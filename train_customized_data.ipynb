# %%
import argparse
import torch
import numpy as np
import random
import os
os.environ['BNB_CUDA_VERSION'] = '118' # need to use Cuda 11.8
os.environ['LD_LIBRARY_PATH']= '/usr/local/cuda-11/lib64' # path to your cuda-11 lib64

# import required modules:

# from exp.exp_model import Exp_Model
from data_load.dataloader import DataLoader
from explain_module.util import summarize_trial, remove_reflections, save_results#, save_agents
from explain_module.agents import PredictReflectAgent
from predict_module.merge_peft_adapter import merge_peft_adapter
from predict_module.supervised_finetune import supervised_finetune
from predict_module.train_reward_model import train_reward_model
from predict_module.tuning_lm_with_rl import tuning_lm_with_rl
from transformers import LlamaTokenizer, pipeline #, AutoModelForCausalLM, BitsAndBytesConfig
from trl import AutoModelForCausalLMWithValueHead
import os, json
import pandas as pd
# Out:
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/utils/generic.py:311: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/bitsandbytes/cuda_setup/main.py:107: UserWarning:
#
# ================================================================================
# WARNING: Manual override via BNB_CUDA_VERSION env variable detected!
# BNB_CUDA_VERSION=XXX can be used to load a bitsandbytes version that is different from the PyTorch CUDA version.
# If this was unintended set the BNB_CUDA_VERSION variable to an empty string: export BNB_CUDA_VERSION=
# If you use the manual override make sure the right libcudart.so is in your LD_LIBRARY_PATH
# For example by adding the following to your .bashrc: export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:<path_to_cuda_dir/lib64
# Loading CUDA version: BNB_CUDA_VERSION=118
# ================================================================================
#
#
#   warn((f'\n\n{"="*80}\n'

# %%
# enter your openai api key
os.environ["OPENAI_API_KEY"] = 'enter_your_openai_api_key_here' # for openai api_key in 'tenacity'

# set the random seed (you set your own seed)
fix_seed = 100
random.seed(fix_seed)
torch.manual_seed(fix_seed)
np.random.seed(fix_seed)

# %%
parser = argparse.ArgumentParser(description='generating')

# load data
parser.add_argument("--price_dir", type=str, default="data/price/preprocessed/")
parser.add_argument("--tweet_dir", type=str, default="data/tweet/raw/")
parser.add_argument("--seq_len", type=int, default=5)

# supervised finetuning
parser.add_argument("--wandb", action="store_true", default=False)
parser.add_argument("--data_path", type=str, default="./data/merge_sample.json")
parser.add_argument("--output_path", type=str, default="./saved_models/lora-Vicuna")
parser.add_argument("--model_path", type=str, default="lmsys/vicuna-7b-v1.5-16k")   
parser.add_argument("--eval_steps", type=int, default=200)
parser.add_argument("--save_steps", type=int, default=200)
parser.add_argument("--resume_from_supervised_checkpoint", type=str, default=None)
parser.add_argument("--ignore_data_skip", type=str, default="False")

# training reward model
parser.add_argument("--num_reflect_trials", type=int, default=2)
parser.add_argument("--datasets_dir", type=str, default="./datasets/")
parser.add_argument('--local_rank', type=int, default=0, help="Used for multi-gpu")
parser.add_argument('--resume_from_reward_checkpoint', type=bool, default=False, help="If you want to resume training where it left off.")
parser.add_argument('--deepspeed', type=str, default=None, help="Path to deepspeed config if using deepspeed. You may need this if the model that you want to train doesn't fit on a single GPU.")
parser.add_argument('--per_device_train_batch_size', type=int, default=1)
parser.add_argument('--per_device_eval_batch_size', type=int, default=1)
parser.add_argument('--reward_gradient_accumulation_steps', type=int, default=32)
parser.add_argument('--reward_learning_rate', type=float, default=2e-5)
parser.add_argument('--weight_decay', type=int, default=0.001)
parser.add_argument('--reward_base_model', type=str, default="lmsys/vicuna-7b-v1.5-16k", help="The model that you want to train from the Hugging Face hub. E.g. gpt2, gpt2-xl, bert, etc.")
parser.add_argument('--bf16', type=bool, default=False, help="This essentially cuts the training time in half if you want to sacrifice a little precision and have a supported GPU.")
parser.add_argument('--num_train_epochs', type=int, default=1, help="The number of training epochs for the reward model.")
parser.add_argument('--train_subset', type=int, default=100000, help="The size of the subset of the training data to use")
parser.add_argument('--eval_subset', type=int, default=50000, help="The size of the subset of the eval data to use")
parser.add_argument('--gradient_checkpointing', type=bool, default=False, help="Enables gradient checkpointing.")
parser.add_argument('--optim', type=str, default="adamw_hf", help="Enables gradient checkpointing.")
parser.add_argument('--lr_scheduler_type', type=str, default="linear", help="The lr scheduler")
parser.add_argument('--reward_adapter', type=str, default="./saved_models/reward_model_vicuna-7b")

# reinforcement learning
parser.add_argument('--rl_base_model', type=str, default="./saved_models/lora-Vicuna-adapter-merged", help="the model name")
parser.add_argument('--tokenizer_name', type=str, default="lmsys/vicuna-7b-v1.5-16k", help="the tokenizer name")
parser.add_argument('--reward_model_name', type=str, default="./saved_models/reward_model_vicuna-7b-adapter-merged", help="the reward model name")
parser.add_argument('--log_with', type=str, default=None, help="use 'wandb' to log with wandb")
parser.add_argument('--rl_learning_rate', type=float, default=1.4e-5, help="the learning rate")
parser.add_argument('--output_max_length', type=int, default=128, help="maximum length for generation")
parser.add_argument('--mini_batch_size', type=int, default=1, help="the PPO minibatch size")
parser.add_argument('--batch_size', type=int, default=1, help="the batch size")
parser.add_argument('--ppo_epochs', type=int, default=4, help="the number of ppo epochs")
parser.add_argument('--rl_gradient_accumulation_steps', type=int, default=1, help="the number of gradient accumulation steps")
parser.add_argument('--adafactor', type=bool, default=False, help="whether to use the adafactor optimizer")
parser.add_argument('--early_stopping', type=bool, default=True, help="whether to early stop")
parser.add_argument('--target_kl', type=float, default=0.1, help="kl target for early stopping")
parser.add_argument('--reward_baseline', type=float, default=0, help="a baseline value that is subtracted from the reward")
parser.add_argument('--batched_gen', type=bool, default=True, help="whether to use the batched text gen")
parser.add_argument('--save_freq', type=int, default=None, help="n steps to save the model")
parser.add_argument('--output_dir', type=str, default="./saved_models/tuning_llama_rl_checkpoints/", help="directory to save the model")
parser.add_argument('--seed', type=int, default=0, help="the seed")
parser.add_argument('--comparison_data_path', type=str, default='./datasets/comparison_data.json')
parser.add_argument('--learning_rate', type=float, default=1.4e-5)

# for evaluation
parser.add_argument("--num_shots", type=int, default=4)
parser.add_argument("--save_dir", type=str, default="results/")

llama_model_path="lmsys/vicuna-7b-v1.5-16k" # 'Llama_models/vicuna-7b-v1.5-16k' # "lmsys/vicuna-7b-v1.5-16k"
args = parser.parse_args(args=[
    '--model_path',llama_model_path,
    '--reward_base_model',llama_model_path,
    '--tokenizer_name',llama_model_path,
    '--price_dir',"data/price/preprocessed/", # "data/sample_price/preprocessed/",
    '--tweet_dir',"data/tweet/raw/", # "data/sample_tweet/raw/",
    '--adafactor',"True",
    '--ppo_epochs','20',
    '--output_max_length','128',
    ])
print('Args in experiment:')
print(args)

dataloader = DataLoader(args)
# Out:
# Args in experiment:
# Namespace(price_dir='data/price/preprocessed/', tweet_dir='data/tweet/raw/', seq_len=5, wandb=False, data_path='./data/merge_sample.json', output_path='./saved_models/lora-Vicuna', model_path='lmsys/vicuna-7b-v1.5-16k', eval_steps=200, save_steps=200, resume_from_supervised_checkpoint=None, ignore_data_skip='False', num_reflect_trials=2, datasets_dir='./datasets/', local_rank=0, resume_from_reward_checkpoint=False, deepspeed=None, per_device_train_batch_size=1, per_device_eval_batch_size=1, reward_gradient_accumulation_steps=32, reward_learning_rate=2e-05, weight_decay=0.001, reward_base_model='lmsys/vicuna-7b-v1.5-16k', bf16=False, num_train_epochs=1, train_subset=100000, eval_subset=50000, gradient_checkpointing=False, optim='adamw_hf', lr_scheduler_type='linear', reward_adapter='./saved_models/reward_model_vicuna-7b', rl_base_model='./saved_models/lora-Vicuna-adapter-merged', tokenizer_name='lmsys/vicuna-7b-v1.5-16k', reward_model_name='./saved_models/reward_model_vicuna-7b-adapter-merged', log_with=None, rl_learning_rate=1.4e-05, output_max_length=128, mini_batch_size=1, batch_size=1, ppo_epochs=20, rl_gradient_accumulation_steps=1, adafactor=True, early_stopping=True, target_kl=0.1, reward_baseline=0, batched_gen=True, save_freq=None, output_dir='./saved_models/tuning_llama_rl_checkpoints/', seed=0, comparison_data_path='./datasets/comparison_data.json', learning_rate=1.4e-05, num_shots=4, save_dir='results/')

# %% [markdown]
# ### 1. train_supervised.py

# %%
# load data

# Collect demonstration data
print("Loading Train Agents...")

data_path='data/customized_df.h5'
if os.path.isfile(data_path):
    data = pd.read_hdf(data_path, 'data')
else:
    # This part costs money!!
    os.environ["OPENAI_API_KEY"] = 'enter_your_openai_api_key_here' # for openai api_key in 'tenacity'
    data = dataloader.load(flag="train")
    data.to_hdf(data_path, key='data', mode='w')

agent_cls = PredictReflectAgent
agents = [agent_cls(row['ticker'], row['summary'], row['target']) for _, row in data.iterrows()]
print("Loaded Train Agents.")
# Out:
# Loading Train Agents...
# Loaded Train Agents.

# %%
# # This part costs money!!
# os.environ["OPENAI_API_KEY"] = 'enter_your_openai_api_key_here' # for openai api_key in 'tenacity'
    
for agent in agents:
    agent.run() # use chatgpt to check the current prediction

    if agent.is_correct():
        prompt = agent._build_agent_prompt()
        response = agent.scratchpad.split('Price Movement: ')[-1]

        sample = {"instruction": prompt, "input": "", "output": response}
        with open(args.data_path, 'a') as f:
            f.write(json.dumps(sample) + "\n")

correct, incorrect = summarize_trial(agents)
print(f'Finished Trial 0, Correct: {len(correct)}, Incorrect: {len(incorrect)}')
# Out:
# Facts:
# 2025-07-19
# - Analysts have raised the price target for NVDA to $192 due to the continued data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the market.
# - Josh Brown suggested selling NVDA shares, citing a reason for doing so.
# - There are stock price predictions for NVIDIA for the year 2025, with different opinions on where it may stand.
# - There is speculation on the surge in market cap and AI leadership for NVDA stock.
# - NVDA stock is being discussed in relation to competitors like AMD and INTC.
# - Morgan Stanley named Nvidia as a top pick ahead of earnings.
# - Jim Cramer predicts a good quarter for NVIDIA.
# - BofA raised the price target for NVDA based on China sales outlook.
# - Dan Niles turned bullish on NVIDIA for certain reasons.
# - Needham maintains a buy rating on NVDA and raises the target to $200.
# - Goldman Sachs gave a buy rating for NVDA, with analysts bullish on the stock.
# - There are discussions on the best stocks to buy now, including NVDA, META, and MSFT.
#
# 2025-07-20
# - Analysts have raised the price target for NVDA stock to $192, with optimistic predictions for the company's data center business.
# - Huawei has introduced a new AI compute platform that poses a challenge to Nvidia in the market.
# - Josh Brown has given followers "permission" to sell NVDA shares, citing reasons for potential concerns.
# - Predictions for NVDA stock price in 2025 vary, with some sources forecasting positive growth.
# - NVDA stock has been named a top pick by some analysts ahead of earnings reports.
# - BofA raised the price target for NVDA based on outlook for China sales.
# - Analysts see long-term upside for NVDA as AI exports to China receive approval.
# - Needham maintains a buy rating on NVDA and increased their target price to $200.
# - Goldman Sachs has given NVDA a buy rating, with bullish analysts predicting positive future performance.
# - NVDA is among the "3 Best Magnificent Seven Stocks to Buy Now" according to Nasdaq.
#
# 2025-07-21
# Nvidia's data center business is continuing to grow, with analysts raising the price target to $192.
# Huawei unveiled a new AI compute platform to challenge Nvidia in the AI space.
# Some analysts, like Josh Brown, have given followers permission to sell Nvidia shares, citing reasons for potential concerns.
# There are conflicting opinions on Nvidia's stock, with some predicting a bullish trend while others discuss competition, market cap surge, and AI leadership.
# Morgan Stanley named Nvidia a top pick ahead of earnings, and BofA raised the price target on the stock based on China sales outlook.
# Analysts see long-term upside for Nvidia as AI exports to China receive a green light.
# Dan Niles explained why he turned bullish on Nvidia, and Needham maintained a buy rating on the stock with a target price of $200.
# Goldman Sachs also gave Nvidia a buy rating, citing reasons for bullish sentiment.
#
# Overall, Nvidia's stock is receiving positive outlooks from analysts, with expectations of growth and potential success in the AI market.
#
# 2025-07-22
# - Nvidia's data center business continues to grow, leading to an analyst raising the price target for NVDA to $192.
# - Huawei introduced a new AI compute platform that challenges Nvidia in the market.
# - Josh Brown advised followers to consider selling Nvidia shares, citing reasons for doing so.
# - There are stock price predictions for NVDA for 2025, with various analysts weighing in on where the stock could be.
# - Despite some concerns, Nvidia remains a top pick ahead of earnings, according to Morgan Stanley.
# - Nvidia stock opinions vary on market cap surge, AI leadership, competition from Huawei, and potential price targets.
# - Analysts see long-term upside for Nvidia as AI technology expands into China, with some firms raising their price targets for NVDA.
# - Investor sentiment appears bullish on Nvidia, with buy ratings from analysts and a positive outlook for the company's performance in the future.
#
# 2025-07-23
# - An analyst lifted the price target for Nvidia (NVDA) to $192, highlighting the continued data center boom.
# - Huawei introduced a new AI compute platform that challenges Nvidia in the market.
# - Some analysts, like Josh Brown, have given followers permission to sell Nvidia shares, citing various reasons.
# - There are predictions about Nvidia's stock price in 2025, with some sources forecasting growth.
# - Investors interested in Nvidia are advised on how to get started with investing in the company.
# - Opinions on Nvidia's market cap surge and AI leadership are discussed.
# - Nvidia's stock has been on a rally as a result of its AI strategy, while also facing competition from Huawei in the AI chip market.
# - Various analysts and firms have given bullish outlooks on Nvidia's stock, raising price targets and maintaining buy ratings.
# - Jim Cramer and Dan Niles both expressed positive sentiments about Nvidia's performance and potential future quarter earnings.
# - Needham reaffirmed a buy rating on Nvidia and raised their price target to $200.
# - Goldman Sachs also gave Nvidia a buy rating, with analysts bullish on the company's prospects.
# - Nvidia is seen as one of the best Magnificent Seven stocks to buy now, along with other companies like Meta and Microsoft.
#
# Price Movement: Positive
#
# Explanation: The series of optimistic developments surrounding NVDA stock, including increased price targets from analysts, positive outlooks on the data center business, and endorsements from key figures like Jim Cramer and Dan Niles, collectively point towards a favorable overall impact on the stock price. Despite potential challenges posed by Huawei's new AI compute platform and mixed predictions for the stock in 2025, the recurring themes of bullish sentiment, buy ratings from reputable firms like Needham and Goldman Sachs, and strategic endorsements position NVDA for positive Price Movement. The consistent growth of NVDA's data center business, coupled with the company's AI leadership and market competitiveness against rivals like AMD and INTC, reinforce the positive trajectory of NVDA stock in response to ongoing developments and market dynamics.
#
#
#
# Facts:
# 2025-07-18
# - Analysts have lifted Nvidia's price target to $192, citing the ongoing data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia's position in the market.
# - Josh Brown advised followers to sell Nvidia shares, providing reasons for his recommendation.
# - Nvidia's stock price in 2025 is predicted to be higher, with various sources providing different forecasts.
# - Despite some concerns, some analysts still consider Nvidia a top pick and bullish on its prospects.
# - Nvidia is seeing a surge in market cap and is perceived as a leader in AI technology.
# - The company is expected to have a good quarter, and some analysts see long-term upside potential, especially with AI exports to China.
# - Several analysts and financial institutions have raised Nvidia's price target, showing optimism about the company's performance and growth potential.
#
# 2025-07-19
# - Analysts have raised the price target for NVDA to $192 due to the continued growth in its data center business.
# - Huawei has introduced a new AI compute platform to challenge NVIDIA in the market.
# - There are varying opinions on NVDA stock, with some analysts and experts bullish on its market cap surge and AI leadership.
# - Some experts, like Josh Brown, have given followers "permission" to sell NVDA shares for certain reasons.
# - NVDA stock price predictions for the future vary, with some sources predicting it could reach $200.
# - NVIDIA has been named a top pick ahead of earnings, with some analysts seeing long-term upside potential.
# - Companies like Morgan Stanley and Goldman Sachs have given positive ratings to NVIDIA, further boosting investor confidence in the stock.
#
# 2025-07-20
# - Analysts have lifted the price target for Nvidia (NVDA) to $192, citing the continued data center boom.
# - Huawei has introduced a new AI compute platform to challenge Nvidia.
# - Investor Josh Brown gave followers 'permission' to sell Nvidia shares for certain reasons.
# - There are various stock price predictions for Nvidia in the future, with one suggesting it could reach $200.
# - Nvidia has been named a top pick ahead of earnings by Morgan Stanley.
# - The company's stock has been receiving positive ratings and forecasts from various analysts and firms.
# - Nvidia's AI leadership and market cap surge have been topics of discussion among investors.
# - Jim Cramer mentioned that Nvidia is expected to have a good quarter.
# - Nvidia's long-term upside potential has been highlighted as AI exports to China receive a green light.
# - BofA raised Nvidia's price target based on positive China sales outlook.
# - Dan Niles explained why he turned bullish on Nvidia.
# - Needham stuck with a buy rating on Nvidia and raised the target to $200.
# - Goldman Sachs gave Nvidia a buy rating, with analysts bullish on the company.
# - Tech stocks like Nvidia, AMD, and INTC are forecasted to look bullish in early trading.
#
# 2025-07-21
# - Nvidia's data center business continues to see growth, prompting an analyst to raise the price target for NVDA stock to $192.
# - Huawei has introduced a new AI compute platform that poses a challenge to Nvidia in the AI market.
# - There are varying opinions on whether to buy or sell Nvidia (NVDA) shares, with some analysts bullish on the stock and others cautious.
# - There are price predictions and forecasts for Nvidia stock in the coming years, with some suggesting potential growth to $200 or beyond.
# - Nvidia has been named a top pick by analysts ahead of earnings reports, with some predicting a good quarter for the company.
# - Analysts are optimistic about Nvidia's long-term prospects, particularly as AI technology gains traction in China.
# - Financial firms like BofA and Needham have raised their price targets for Nvidia stock based on factors like China sales outlook and AI leadership.
# - Goldman Sachs has given Nvidia a buy rating, citing reasons why analysts are bullish on the stock.
# - Nvidia is considered one of the top "Magnificent Seven" stocks to buy now, along with other companies like Meta and Microsoft.
#
# 2025-07-22
# - Analysts have lifted Nvidia's (NVDA) price target to $192, citing the ongoing data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the AI space.
# - There are differing opinions on Nvidia's stock (NVDA), with some analysts giving permission to sell shares while others predict a price increase to $200.
# - Despite competition from Huawei, Nvidia remains a top pick, with analysts seeing long-term upside potential as AI technology expands.
# - Jim Cramer believes Nvidia (NVDA) will have a good quarter, while Dan Niles has turned bullish on the company.
# - Needham has a buy rating on Nvidia and has lifted the target price to $200.
# - Goldman Sachs has also given Nvidia (NVDA) a buy rating, and analysts are bullish on the stock.
# - Nvidia is considered one of the three best stocks to buy now, along with META and Microsoft (MSFT).
#
# Price Movement: Positive
#
# Explanation: The overall impact of the provided facts on the price movement of NVDA stock is positive. Analysts' increased price targets for Nvidia, based on the data center boom and long-term growth potential, reflect optimism in the company's performance. While Huawei's new AI platform poses a challenge, Nvidia's market leadership in AI and surge in market cap are viewed positively. Despite varying opinions, with suggestions to sell shares like Josh Brown or predictions of price increases to $200, the consensus remains bullish on NVDA. Positive ratings from financial institutions like BofA and Goldman Sachs, as well as notable investors turning bullish on the stock, further contribute to the optimistic outlook for Nvidia. The continuous growth in Nvidia's data center business and anticipation of a good quarter solidify the positive sentiment around the stock, supported by analysts' forecasts and recognition of the company as a top pick in the market.
#
#
#
# Facts:
# 2025-07-17
# - An analyst raised the price target for NVIDIA (NVDA) to $192 due to the continued growth in its data center business.
# - Huawei introduced a new AI compute platform that challenges NVIDIA's position in the market.
# - There are opinions and predictions about NVIDIA's stock price performance in the future, with some analysts bullish on the company.
# - Josh Brown suggested selling NVIDIA shares, citing reasons for doing so.
# - NVIDIA was named a top pick ahead of earnings by Morgan Stanley and received a buy rating from Goldman Sachs.
# - Analysts see long-term upside for NVIDIA as AI exports to China get the green light.
# - NVIDIA is forecasted to have a good quarter, with an increased price target by Bank of America.
# - Dan Niles turned bullish on NVIDIA, explaining his reasoning for his positive outlook on the stock.
# - Needham maintained a Buy rating on NVIDIA and raised the target price to $200.
# - Tech stocks like NVIDIA, AMD, and INTC are looking bullish in early trading according to some reports.
#
# 2025-07-18
# -Nvidia's data center business is experiencing continued growth, prompting an analyst to raise the price target for NVDA stock to $192.
# -There is competition for Nvidia from Huawei with a new AI compute platform challenging Nvidia's position in the market.
# -There are conflicting opinions on NVDA stock, with Josh Brown giving followers "permission" to sell Nvidia shares due to reasons not specified.
# -There are varying stock price predictions for Nvidia in 2025, with some sources bullish on the stock reaching $200.
# -Morgan Stanley named Nvidia a top pick ahead of earnings, suggesting positive outlook for the company.
# -Various analysts and firms have raised price targets for Nvidia, with BofA raising the target based on China sales outlook and Needham sticking with a buy rating and lifting the target to $200.
# -Jim Cramer believes Nvidia will have a good quarter, while Dan Niles explains his bullish stance on Nvidia.
# -Overall, analysts see long-term upside for Nvidia as AI exports to China get the green light and the company continues to lead in AI technology.
# -Nvidia has recently received a buy rating from Goldman Sachs, further contributing to the positive sentiment around the stock.
# -Overall, Nvidia is considered one of the best Magnificent Seven stocks to buy now for potential growth.
#
# 2025-07-19
# - Analysts have lifted Nvidia's price target to $192, with the company experiencing a data center boom.
# - Huawei has unveiled a new AI compute platform to challenge Nvidia in the AI space.
# - There are differing opinions on whether to sell or invest in Nvidia shares, with Josh Brown giving followers "permission" to sell.
# - There are stock price predictions for Nvidia in 2025, with some sources bullish on the company's future.
# - Nvidia's market cap has surged, and the company is seen as a leader in AI technology.
# - Nvidia has been named a top pick by analysts ahead of earnings reports.
# - There are positive outlooks on Nvidia's performance, with some analysts seeing long-term upside potential as AI exports to China get a green light.
# - Analysts at Needham have reiterated their buy rating on Nvidia and raised their price target to $200.
# - Goldman Sachs has given Nvidia a buy rating, citing reasons for being bullish on the company.
# - Nvidia is among the "Magnificent Seven Stocks" recommended for investment.
#
# 2025-07-20
# 1. Analysts have raised the price target for NVIDIA (NVDA) to $192, citing a continued data center boom.
# 2. Huawei has introduced a new AI compute platform, challenging NVIDIA in the AI space.
# 3. There is a mixed opinion on investing in NVIDIA, with some analysts giving permission to sell shares while others name it a top pick.
# 4. NVIDIA's stock price is predicted to potentially reach $200 in the future.
# 5. Financial experts have a bullish outlook on tech stocks like NVDA, AMD, and INTC.
# 6. Analysts anticipate long-term upside for NVIDIA as AI exports to China receive approval.
# 7. Several analysts and financial firms have raised their price targets for NVIDIA, with some setting it at $200.
# 8. Jim Cramer predicts that NVIDIA will have a good quarter based on their performance.
# 9. NVIDIA has been named a top pick ahead of earnings by Morgan Stanley.
# 10. Recent reports indicate that NVIDIA just received a buy rating from Goldman Sachs.
#
# 2025-07-21
# - Analysts have raised price targets for NVDA, with predictions ranging up to $200.
# - Huawei has unveiled a new AI compute platform that challenges Nvidia in the AI space.
# - There is debate among experts such as Josh Brown on whether to buy or sell NVDA shares.
# - NVDA is considered a top pick by analysts ahead of earnings reports.
# - NVDA has been named a leader in AI technology and has seen a surge in market cap.
# - Nvidia's long-term upside is seen by analysts, especially as their AI technology exports to China get approval.
# - Jim Cramer believes NVDA will have a good quarter.
# - NVDA stock is predicted to continue its bullish trend in early trading.
# - Dan Niles has turned bullish on NVDA.
# - Needham has a buy rating on NVDA and has raised its target price to $200.
#
# Price Movement: Positive
#
# Explanation: The overall impact of the facts suggests a positive price movement for NVDA stock. Analysts have raised the price target for NVIDIA multiple times, citing the continued growth in its data center business and the company's leadership in AI technology. Despite competition from Huawei, the optimistic outlook on NVIDIA's performance, especially with advancements in AI exports to China, bodes well for its future growth. Various analysts and financial firms, including Morgan Stanley, Goldman Sachs, and Needham, have reiterated buy ratings and raised price targets, indicating strong confidence in NVIDIA's prospects. Jim Cramer's positive quarter prediction further supports the bullish sentiment surrounding NVDA stock. Additionally, the stock being named a top pick ahead of earnings reports and its inclusion among the recommended "Magnificent Seven Stocks" highlight the robust potential for NVDA to sustain its upward price trajectory.
#
#
#
# Facts:
# 2025-07-16
# - Analysts have lifted Nvidia's price target to $192, indicating continued growth in the data center sector.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the AI space.
# - Some investors, like Josh Brown, have given followers "permission" to sell Nvidia shares for various reasons.
# - There are stock price predictions for Nvidia in 2025, with differing opinions on where the stock will be.
# - Despite competition and challenges, Nvidia stock has been named a top pick by some analysts ahead of earnings.
# - Various analysts and firms have raised price targets for Nvidia, with positive outlooks on the company's performance and potential.
# - Jim Cramer and Dan Niles have expressed bullish sentiments regarding Nvidia's future performance.
# - Nvidia has been recommended as a buy by multiple analysts, with price targets ranging from $200 to higher values.
# - The company's growth in the AI sector and potential opportunities in China have been highlighted as factors for long-term upside.
# - Nvidia has been included in lists of best stocks to buy, indicating positive sentiment towards the company's potential for growth.
#
# 2025-07-17
# - Analysts have lifted the price target for Nvidia (NVDA) to $192, citing the continued data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the AI space.
# - There are varying opinions on whether to sell Nvidia shares, with some analysts recommending it.
# - Nvidia's stock price prediction for 2025 is being discussed, with some sources bullish on the company's prospects.
# - Nvidia has been named a top pick ahead of earnings by Morgan Stanley.
# - Various analysts have different perspectives on Nvidia's market cap surge, AI leadership, and competition from Huawei in the AI chip space.
# - Some analysts believe Nvidia is poised for long-term upside as AI exports to China receive approval.
# - Financial institutions like BofA and Needham have raised their price targets for Nvidia.
# - Dan Niles has turned bullish on Nvidia, explaining his reasons for the shift in sentiment.
# - Goldman Sachs has given Nvidia a buy rating, with analysts bullish on the company's future prospects.
# - Tech stocks like Nvidia, AMD, and INTC are forecasted to look bullish in early trading.
# - Forbes has discussed the potential for Nvidia's stock to reach $200.
#
# 2025-07-18
# Analysts have raised the price target for NVIDIA (NVDA) to $192, citing continued growth in the data center sector.
#
# Huawei has introduced a new AI compute platform that poses a challenge to NVIDIA in the AI market.
#
# Josh Brown recommended selling NVIDIA shares, raising concerns about the company's future performance.
#
# There are conflicting opinions on the market cap surge and AI leadership of NVIDIA stock.
#
# Morgan Stanley named NVIDIA a top pick ahead of earnings, predicting positive performance.
#
# Various analysts and sources have provided price predictions for NVIDIA stock in the coming years, with estimates ranging from $200 to unknown figures in 2025, 2026, and 2030.
#
# Jim Cramer and other analysts are optimistic about NVIDIA's upcoming quarter and long-term prospects, especially in light of AI exports to China.
#
# BofA raised their price target for NVIDIA based on strong sales outlook in China.
#
# Dan Niles explained his bullish stance on NVIDIA, highlighting positive factors driving the stock's performance.
#
# Overall, analysts see long-term upside for NVIDIA as the company continues to dominate in the AI market and receives positive ratings from analysts.
#
# 2025-07-19
# - Analysts have lifted the price target for NVDA to $192 due to the continued data center boom
# - Huawei has challenged Nvidia with a new AI compute platform
# - Josh Brown gave followers "permission" to sell Nvidia shares for certain reasons
# - There are stock price predictions for NVDA in 2025, with expectations for growth
# - Nvidia has been named a top pick by analysts ahead of earnings reports
# - Various analysts and firms have given buy ratings and raised price targets for NVDA, with bullish outlooks on the stock
# - NVDA stock has been performing well, with tech stocks looking bullish in early trading
# - Jim Cramer and Dan Niles have expressed positive sentiments towards Nvidia and its potential for growth
# - Needham has reiterated a buy rating on Nvidia and lifted the target price to $200
#
# 2025-07-20
# - Analysts have raised price targets for NVDA stock to as high as $192 and potentially $200.
# - Huawei has introduced a new AI compute platform that challenges Nvidia's position in the market.
# - Investor Josh Brown gave followers "permission" to sell NVIDIA shares for reasons not specified in the tweets.
# - Morgan Stanley named Nvidia a top pick ahead of earnings, indicating positive outlook.
# - NVDA stock is forecasted to look bullish in early trading, along with other tech stocks like AMD and INTC.
# - Dan Niles turned bullish on Nvidia, explaining his reasoning.
# - Needham reiterated a Buy rating on Nvidia and raised the target to $200.
# - The stock price predictions for Nvidia range from where it could be by 2025, 2026, and 2030.
# - Jim Cramer believes NVIDIA will have a good quarter.
# - BofA raised Nvidia's price target based on the outlook for China sales.
# - Nvidia is seen as a leader in AI and data center technologies, driving market cap surge and AI leadership opinions.
#
# Price Movement: Positive
#
# Explanation: Despite some challenges in the AI space from competitors like Huawei and conflicting opinions on selling Nvidia shares, the overall sentiment surrounding Nvidia stock remains positive. Analysts have continued to raise price targets, with many emphasizing the company's growth potential in the data center sector. Positive endorsements from figures like Jim Cramer and Dan Niles, along with recommendations from various analysts to buy Nvidia stock and bullish outlooks on the company's future performance, indicate a favorable Price Movement for NVDA shares. The stock's inclusion in lists of best stocks to buy, along with raised price targets and reiterated buy ratings by financial institutions like BofA and Needham, highlight the optimism surrounding Nvidia's long-term upside potential despite the competitive landscape.
#
#
#
# Facts:
# 2025-07-15
# - Analysts are bullish on NVIDIA's stock (NVDA), with price targets being lifted to $192, $200, and even $200-plus.
# - NVIDIA's data center business continues to boom, leading to optimism among investors and analysts.
# - Huawei has unveiled a new AI compute platform that challenges NVIDIA in the AI chip competition.
# - Despite some analysts giving permission to sell NVIDIA shares, others see long-term upside potential for the company.
# - NVIDIA has been named a top pick ahead of earnings by some analysts, with positive outlooks for the company's performance.
# - The company's strong AI leadership and market cap surge have been noted by analysts and financial experts.
# - Needham maintains a buy rating on NVIDIA stock and has lifted their target to $200.
# - Dan Niles has turned bullish on NVIDIA, adding to the positive sentiment surrounding the company's stock.
#
# 2025-07-16
# - Analysts are bullish on Nvidia (NVDA), with price targets as high as $200 and recommendations to buy the stock.
# - Nvidia's data center business continues to grow, with one analyst raising the price target to $192.
# - Huawei has unveiled a new AI compute platform that challenges Nvidia in the AI space.
# - Despite the positive outlook, some, like Josh Brown, have given followers "permission" to sell NVDA shares.
# - Nvidia has been named a top pick ahead of earnings by some analysts.
# - The company is poised to have a good quarter, according to Jim Cramer.
# - Needham maintains a buy rating on Nvidia, with a target price of $200.
# - Dan Niles has turned bullish on Nvidia, citing positive prospects for the company.
# - Analysts see long-term upside for Nvidia as AI exports to China get the green light.
# - Goldman Sachs has given Nvidia a buy rating, with analysts bullish on the stock.
# - Tech stocks like Nvidia, AMD, and INTC are looking bullish in early trading.
# - 24/7 Wall St. predicts Nvidia's stock price in 2025.
# - Quiver Quantitative provides insights on Nvidia's market cap surge and AI leadership.
# - Investopedia offers advice on how to start investing in Nvidia stock.
# - Nvidia is facing competition in the AI chip space from companies like Huawei.
# - BofA raises Nvidia's price target based on China sales outlook.
#
# 2025-07-17
# - Analysts have been bullish on NVDA, with price targets as high as $192 and $200.
# - There is competition in the AI chip market, with Huawei unveiling a rival AI platform challenging NVIDIA.
# - Despite some analysts giving permission to sell NVDA shares, others believe in its long-term upside potential.
# - NVDA has been named a top pick ahead of earnings by some analysts.
# - The stock price prediction for NVDA in 2025, 2026, and 2030 varies, but there is optimism surrounding the company's performance.
# - China sales outlook has influenced price target raises by analysts.
# - Jim Cramer believes NVDA is going to have a good quarter.
# - NVDA remains a buy for some analysts, with price targets being raised to as high as $200.
#
# Price Movement: Positive
#
# Explanation: Analysts' bullish sentiments and optimistic price targets for NVIDIA's stock (NVDA) indicate positive momentum and growth potential for the company. The continued success of NVIDIA's data center business and its strong position in the AI chip market are contributing to investor confidence and driving share price expectations upward. Despite competition from Huawei in the AI space, analysts see long-term upside for NVIDIA, with buy ratings maintained and target prices raised. The company's leadership in AI and market cap surge further support the positive outlook, with experts like Jim Cramer anticipating a strong quarter. Overall, the collective optimism from analysts and financial experts suggests a favorable Price Movement for NVDA stock in response to its promising performance and growth prospects.
#
#
#
# Facts:
# 2025-07-15
# - Analysts lifted Nvidia's price target to $192 due to the continued data center boom.
# - Huawei challenged Nvidia with a new AI compute platform.
# - Josh Brown gave followers 'permission' to sell Nvidia shares for unspecified reasons.
# - There are varying opinions and predictions about Nvidia's stock price in 2025.
# - Nvidia stock surged due to market cap and AI leadership.
# - Nvidia's stock could potentially reach $200 according to Forbes.
# - Tech stocks like Nvidia, AMD, and INTC are forecasted to look bullish in early trading.
# - Nvidia was named a top pick ahead of earnings by Morgan Stanley.
# - Jim Cramer believes Nvidia will have a good quarter.
# - BofA raised Nvidia's price target based on China sales outlook.
# - Dan Niles turned bullish on Nvidia for undisclosed reasons.
# - Analysts see long-term upside for Nvidia as AI exports to China get approved.
# - Needham stuck with a buy rating on Nvidia and lifted the target to $200.
# - Nvidia received a buy rating from Goldman Sachs for bullish reasons.
# - Nvidia is considered one of the 3 best Magnificent Seven stocks to buy now alongside META and MSFT.
#
# 2025-07-16
# -Nvidia's data center business is experiencing growth, leading an analyst to increase the price target for NVDA stock to $192.
# -Huawei has introduced a new AI compute platform that challenges Nvidia in the market.
# -Josh Brown, a financial analyst, advised followers to sell their Nvidia shares for specific reasons.
# -There are predictions and opinions on Nvidia's stock price for 2025, with some sources bullish on the company's performance.
# -Nvidia is being named a top pick by some analysts ahead of its earnings report.
# -Various analysts and financial institutions are raising price targets for Nvidia stock based on factors like China sales outlook and AI leadership.
# -Nvidia's stock price is experiencing bullish trends in early trading, along with other tech stocks like AMD and INTC.
# -Experts like Jim Cramer and Dan Niles have expressed positive sentiments towards Nvidia's performance and outlook.
# -Needham reiterates a buy rating for Nvidia stock and raises the target price to $200.
# -Goldman Sachs has given Nvidia a buy rating, with analysts optimistic about the company's future prospects.
# -Nvidia is identified as one of the best "Magnificent Seven" stocks to buy now, alongside companies like Meta and Microsoft.
#
# Price Movement: Positive
#
# Explanation: A series of positive developments and endorsements have fueled optimism around NVDA stock, leading to a favorable Price Movement. Analysts increasing the price target to $192 due to the data center boom showcases confidence in Nvidia's growth prospects. Despite competition from Huawei's new AI compute platform, the stock surged, reflecting its market cap and AI leadership. Various experts like Jim Cramer and Dan Niles have expressed bullish sentiments and support for Nvidia's strong performance. Analysts issuing buy ratings and raising price targets, such as Morgan Stanley and Needham, highlight the positive outlook on Nvidia's future. The company's long-term potential, especially in AI exports to China, further solidifies the positive Price Movement surrounding NVDA stock. Therefore, the overall impact suggests a positive trajectory for Nvidia's stock price.
#
#
#
# Finished Trial 0, Correct: 6, Incorrect: 0

# %%
# Train supervised policy
supervised_finetune(args)
merge_peft_adapter(model_name=args.output_path, output_name=args.rl_base_model)
# Out:
# lmsys/vicuna-7b-v1.5-16k
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# trainable params: 4,194,304 || all params: 6,742,609,920 || trainable%: 0.06220594176090199
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/accelerate/accelerator.py:449: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)
#  If there's a warning about missing keys above, please disregard :)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/bitsandbytes/nn/modules.py:226: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.')
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:03, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# peft_config:  LoraConfig(peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path='lmsys/vicuna-7b-v1.5-16k', revision=None, task_type='CAUSAL_LM', inference_mode=True, r=8, target_modules={'v_proj', 'q_proj'}, lora_alpha=16, lora_dropout=0.05, fan_in_fan_out=False, bias='none', modules_to_save=None, init_lora_weights=True, layers_to_transform=None, layers_pattern=None, rank_pattern={}, alpha_pattern={})
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:508: UserWarning: The generation config instance is invalid -- `.validate()` throws warnings and/or exceptions. Fix these issues to save the configuration. This warning will be raised to an exception in v4.34.
#
# Thrown during validation:
# `do_sample` is set to `False`. However, `temperature` is set to `None` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(

# %%
# Collect comparison data
comparison_data = []

# os.environ["OPENAI_API_KEY"] = 'enter_your_openai_api_key_here' # for openai api_key in 'tenacity'
    
# This part costs money!!
for trial in range(args.num_reflect_trials):
    for idx, agent in enumerate([a for a in agents if not a.is_correct()]):
        prev_response = agent.scratchpad.split('Price Movement: ')[-1]
        agent.run()

        if agent.is_correct():
            print(agent._build_agent_prompt(), "\n\n\n")
            prompt = remove_reflections(agent._build_agent_prompt())
            response = agent.scratchpad.split('Price Movement: ')[-1]

            sample = {"user_input": prompt, "completion_a": prev_response, "completion_b": response}
            comparison_data.append(sample)
            # print(sample)

    correct, incorrect = summarize_trial(agents)
    print(f'Finished Trial {trial+1}, Correct: {len(correct)}, Incorrect: {len(incorrect)}')

os.makedirs(args.datasets_dir, exist_ok=True)
comparison_data_path = os.path.join(args.datasets_dir, "comparison_data.json")

if comparison_data:
    with open(comparison_data_path, 'w') as f:
        f.write(json.dumps(comparison_data))
# Out:
# Facts:
# 2025-07-19
# - Analysts have raised the price target for NVDA to $192 due to the continued data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the market.
# - Josh Brown suggested selling NVDA shares, citing a reason for doing so.
# - There are stock price predictions for NVIDIA for the year 2025, with different opinions on where it may stand.
# - There is speculation on the surge in market cap and AI leadership for NVDA stock.
# - NVDA stock is being discussed in relation to competitors like AMD and INTC.
# - Morgan Stanley named Nvidia as a top pick ahead of earnings.
# - Jim Cramer predicts a good quarter for NVIDIA.
# - BofA raised the price target for NVDA based on China sales outlook.
# - Dan Niles turned bullish on NVIDIA for certain reasons.
# - Needham maintains a buy rating on NVDA and raises the target to $200.
# - Goldman Sachs gave a buy rating for NVDA, with analysts bullish on the stock.
# - There are discussions on the best stocks to buy now, including NVDA, META, and MSFT.
#
# 2025-07-20
# - Analysts have raised the price target for NVDA stock to $192, with optimistic predictions for the company's data center business.
# - Huawei has introduced a new AI compute platform that poses a challenge to Nvidia in the market.
# - Josh Brown has given followers "permission" to sell NVDA shares, citing reasons for potential concerns.
# - Predictions for NVDA stock price in 2025 vary, with some sources forecasting positive growth.
# - NVDA stock has been named a top pick by some analysts ahead of earnings reports.
# - BofA raised the price target for NVDA based on outlook for China sales.
# - Analysts see long-term upside for NVDA as AI exports to China receive approval.
# - Needham maintains a buy rating on NVDA and increased their target price to $200.
# - Goldman Sachs has given NVDA a buy rating, with bullish analysts predicting positive future performance.
# - NVDA is among the "3 Best Magnificent Seven Stocks to Buy Now" according to Nasdaq.
#
# 2025-07-21
# Nvidia's data center business is continuing to grow, with analysts raising the price target to $192.
# Huawei unveiled a new AI compute platform to challenge Nvidia in the AI space.
# Some analysts, like Josh Brown, have given followers permission to sell Nvidia shares, citing reasons for potential concerns.
# There are conflicting opinions on Nvidia's stock, with some predicting a bullish trend while others discuss competition, market cap surge, and AI leadership.
# Morgan Stanley named Nvidia a top pick ahead of earnings, and BofA raised the price target on the stock based on China sales outlook.
# Analysts see long-term upside for Nvidia as AI exports to China receive a green light.
# Dan Niles explained why he turned bullish on Nvidia, and Needham maintained a buy rating on the stock with a target price of $200.
# Goldman Sachs also gave Nvidia a buy rating, citing reasons for bullish sentiment.
#
# Overall, Nvidia's stock is receiving positive outlooks from analysts, with expectations of growth and potential success in the AI market.
#
# 2025-07-22
# - Nvidia's data center business continues to grow, leading to an analyst raising the price target for NVDA to $192.
# - Huawei introduced a new AI compute platform that challenges Nvidia in the market.
# - Josh Brown advised followers to consider selling Nvidia shares, citing reasons for doing so.
# - There are stock price predictions for NVDA for 2025, with various analysts weighing in on where the stock could be.
# - Despite some concerns, Nvidia remains a top pick ahead of earnings, according to Morgan Stanley.
# - Nvidia stock opinions vary on market cap surge, AI leadership, competition from Huawei, and potential price targets.
# - Analysts see long-term upside for Nvidia as AI technology expands into China, with some firms raising their price targets for NVDA.
# - Investor sentiment appears bullish on Nvidia, with buy ratings from analysts and a positive outlook for the company's performance in the future.
#
# 2025-07-23
# - An analyst lifted the price target for Nvidia (NVDA) to $192, highlighting the continued data center boom.
# - Huawei introduced a new AI compute platform that challenges Nvidia in the market.
# - Some analysts, like Josh Brown, have given followers permission to sell Nvidia shares, citing various reasons.
# - There are predictions about Nvidia's stock price in 2025, with some sources forecasting growth.
# - Investors interested in Nvidia are advised on how to get started with investing in the company.
# - Opinions on Nvidia's market cap surge and AI leadership are discussed.
# - Nvidia's stock has been on a rally as a result of its AI strategy, while also facing competition from Huawei in the AI chip market.
# - Various analysts and firms have given bullish outlooks on Nvidia's stock, raising price targets and maintaining buy ratings.
# - Jim Cramer and Dan Niles both expressed positive sentiments about Nvidia's performance and potential future quarter earnings.
# - Needham reaffirmed a buy rating on Nvidia and raised their price target to $200.
# - Goldman Sachs also gave Nvidia a buy rating, with analysts bullish on the company's prospects.
# - Nvidia is seen as one of the best Magnificent Seven stocks to buy now, along with other companies like Meta and Microsoft.
#
# Price Movement: Positive
#
# Explanation: The series of factors surrounding NVDA stock, including raised price targets by analysts, the continued growth of its data center business, and positive sentiments from market influencers like Jim Cramer and Dan Niles, collectively indicate a positive Price Movement. Despite concerns raised by Josh Brown and competition from Huawei's new AI compute platform, the overall outlook for NVDA remains bullish, with projections of further growth, potential success in the AI market, and investor confidence reflected in buy ratings and increased price targets from multiple firms. These factors contribute to an optimistic forecast for NVDA's stock performance.
#
#
#
# Given a list of facts, estimate their overall impact on the price movement of NVDA stock. Give your response in this format:
# (1) Price Movement, which should be either Positive or Negative.
# (2) Explanation, which should be in a single, short paragraph.
# Here are some examples:
# Facts:
# 2016-07-26
# Apple reported Q3 2016 earnings: Revenue of $42.4 billion, beating expectations. They sold 40.4 million iPhones, 9.9 million iPads, and 4.2 million Macs during that quarter.
# Apple's earnings beat expectations, causing the stock to rise by almost 5% in after-hours trading.
# Apple had $231.5 billion in cash reserves, enough to potentially acquire companies like Uber, Tesla, Twitter, Airbnb, Netflix, Snapchat, and SpaceX and still have billions left.
# Apple's China sales were down around 29% sequentially and 33% YoY.
# Despite declining unit sales, Apple's revenue was boosted by more expensive iPad Pro models.
# Apple Pay accounted for 3/4 of contactless payments in the US.
# Apple's services business (App Store, Apple Music, etc.) was projected to be the size of a Fortune 500 company in the next year.
# Apple was reported to be working on a car project called Project Titan, with Bob Mansfield leading it.
# The Apple Pencil was granted a patent to work with a Mac's trackpad.
# Apple faced declining iPhone sales, but the company focused on promoting apps and services.
# The stock price experienced fluctuations after the earnings report, with significant after-hours gains.
# Apple's market weight rating was reiterated by Wells Fargo, with a target price of $120.00.
#
# Price Movement: Positive
#
# Explanation: Apple reported strong Q3 2016 earnings, surpassing revenue expectations and delivering robust sales figures across its product lines, including iPhones, iPads, and Macs. This performance exceeded market projections and triggered a nearly 5% increase in the stock's after-hours trading. Additionally, Apple's substantial cash reserves of $231.5 billion, capable of facilitating major acquisitions, demonstrated the company's financial stability and growth potential. Despite challenges in China, Apple's diverse revenue sources, including higher-priced iPad Pro models and the dominant Apple Pay in US contactless payments, contributed positively to its overall Price Movement. The promising growth trajectory of Apple's services business added further optimism. While facing declining iPhone sales, Apple's strategic focus on promoting apps and services reflected adaptability in response to changing market dynamics. The consistent support from Wells Fargo with a reiterated market weight rating and target price also reinforced investor confidence. The stock's fluctuations were notable but aligned with the positive earnings report, showcasing the market's responsiveness to Apple's performance.
#
# Facts:
# 2016-04-26
# Apple reported its Q2 2016 earnings, missing both profit and revenue estimates.
# Apple's revenue for the quarter was $50.56 billion, falling short of the estimated $52 billion.
# The company's adjusted earnings per share (EPS) was $1.90, lower than the expected $2.00.
# This marks the first time in 13 years that Apple experienced a quarterly decline in revenue.
# iPhone sales experienced a decline for the first time since its debut in 2007.
# The company's guidance for the next quarter indicates expected sales of $41 billion to $43 billion.
# Apple's dividend yield increased to 2.3%.
# CEO Tim Cook attributed the challenges to strong macroeconomic headwinds, especially in China.
# Despite the earnings miss, Apple announced plans to raise its dividend and return $50 billion more to shareholders.
# Apple's stock price experienced a decline of around 4.8% in after-hours trading following the earnings report.
#
# Price Movement: Negative
#
# Explanation: Apple reported disappointing Q2 2016 earnings, missing both profit and revenue estimates. The company's revenue and adjusted earnings per share fell short of expectations, marking the first quarterly revenue decline in 13 years. iPhone sales, a cornerstone of Apple's business, experienced their first-ever decline since the product's debut in 2007. The weaker-than-expected guidance for the next quarter further dampened investor Price Movement. The CEO's acknowledgment of strong macroeconomic headwinds, particularly in China, indicated external challenges affecting the company's performance. Despite announcing plans to increase dividends and return more to shareholders, the stock price plunged around 4.8% in after-hours trading following the earnings report. Overall, these factors collectively indicate a negative Price Movement surrounding AAPL stock due to its underwhelming financial performance and market outlook.
#
# (END OF EXAMPLES)
#
#
#
# Facts:
# 2025-07-19
# - Analysts have raised the price target for NVDA to $192 due to the continued data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the market.
# - Josh Brown suggested selling NVDA shares, citing a reason for doing so.
# - There are stock price predictions for NVIDIA for the year 2025, with different opinions on where it may stand.
# - There is speculation on the surge in market cap and AI leadership for NVDA stock.
# - NVDA stock is being discussed in relation to competitors like AMD and INTC.
# - Morgan Stanley named Nvidia as a top pick ahead of earnings.
# - Jim Cramer predicts a good quarter for NVIDIA.
# - BofA raised the price target for NVDA based on China sales outlook.
# - Dan Niles turned bullish on NVIDIA for certain reasons.
# - Needham maintains a buy rating on NVDA and raises the target to $200.
# - Goldman Sachs gave a buy rating for NVDA, with analysts bullish on the stock.
# - There are discussions on the best stocks to buy now, including NVDA, META, and MSFT.
#
# 2025-07-20
# - Analysts have raised the price target for NVDA stock to $192, with optimistic predictions for the company's data center business.
# - Huawei has introduced a new AI compute platform that poses a challenge to Nvidia in the market.
# - Josh Brown has given followers "permission" to sell NVDA shares, citing reasons for potential concerns.
# - Predictions for NVDA stock price in 2025 vary, with some sources forecasting positive growth.
# - NVDA stock has been named a top pick by some analysts ahead of earnings reports.
# - BofA raised the price target for NVDA based on outlook for China sales.
# - Analysts see long-term upside for NVDA as AI exports to China receive approval.
# - Needham maintains a buy rating on NVDA and increased their target price to $200.
# - Goldman Sachs has given NVDA a buy rating, with bullish analysts predicting positive future performance.
# - NVDA is among the "3 Best Magnificent Seven Stocks to Buy Now" according to Nasdaq.
#
# 2025-07-21
# Nvidia's data center business is continuing to grow, with analysts raising the price target to $192.
# Huawei unveiled a new AI compute platform to challenge Nvidia in the AI space.
# Some analysts, like Josh Brown, have given followers permission to sell Nvidia shares, citing reasons for potential concerns.
# There are conflicting opinions on Nvidia's stock, with some predicting a bullish trend while others discuss competition, market cap surge, and AI leadership.
# Morgan Stanley named Nvidia a top pick ahead of earnings, and BofA raised the price target on the stock based on China sales outlook.
# Analysts see long-term upside for Nvidia as AI exports to China receive a green light.
# Dan Niles explained why he turned bullish on Nvidia, and Needham maintained a buy rating on the stock with a target price of $200.
# Goldman Sachs also gave Nvidia a buy rating, citing reasons for bullish sentiment.
#
# Overall, Nvidia's stock is receiving positive outlooks from analysts, with expectations of growth and potential success in the AI market.
#
# 2025-07-22
# - Nvidia's data center business continues to grow, leading to an analyst raising the price target for NVDA to $192.
# - Huawei introduced a new AI compute platform that challenges Nvidia in the market.
# - Josh Brown advised followers to consider selling Nvidia shares, citing reasons for doing so.
# - There are stock price predictions for NVDA for 2025, with various analysts weighing in on where the stock could be.
# - Despite some concerns, Nvidia remains a top pick ahead of earnings, according to Morgan Stanley.
# - Nvidia stock opinions vary on market cap surge, AI leadership, competition from Huawei, and potential price targets.
# - Analysts see long-term upside for Nvidia as AI technology expands into China, with some firms raising their price targets for NVDA.
# - Investor sentiment appears bullish on Nvidia, with buy ratings from analysts and a positive outlook for the company's performance in the future.
#
# 2025-07-23
# - An analyst lifted the price target for Nvidia (NVDA) to $192, highlighting the continued data center boom.
# - Huawei introduced a new AI compute platform that challenges Nvidia in the market.
# - Some analysts, like Josh Brown, have given followers permission to sell Nvidia shares, citing various reasons.
# - There are predictions about Nvidia's stock price in 2025, with some sources forecasting growth.
# - Investors interested in Nvidia are advised on how to get started with investing in the company.
# - Opinions on Nvidia's market cap surge and AI leadership are discussed.
# - Nvidia's stock has been on a rally as a result of its AI strategy, while also facing competition from Huawei in the AI chip market.
# - Various analysts and firms have given bullish outlooks on Nvidia's stock, raising price targets and maintaining buy ratings.
# - Jim Cramer and Dan Niles both expressed positive sentiments about Nvidia's performance and potential future quarter earnings.
# - Needham reaffirmed a buy rating on Nvidia and raised their price target to $200.
# - Goldman Sachs also gave Nvidia a buy rating, with analysts bullish on the company's prospects.
# - Nvidia is seen as one of the best Magnificent Seven stocks to buy now, along with other companies like Meta and Microsoft.
#
# Price Movement:
#
#
#
# {'user_input': 'Given a list of facts, estimate their overall impact on the price movement of NVDA stock. Give your response in this format:\n(1) Price Movement, which should be either Positive or Negative.\n(2) Explanation, which should be in a single, short paragraph.\nHere are some examples:\nFacts:\n2016-07-26\nApple reported Q3 2016 earnings: Revenue of $42.4 billion, beating expectations. They sold 40.4 million iPhones, 9.9 million iPads, and 4.2 million Macs during that quarter.\nApple\'s earnings beat expectations, causing the stock to rise by almost 5% in after-hours trading.\nApple had $231.5 billion in cash reserves, enough to potentially acquire companies like Uber, Tesla, Twitter, Airbnb, Netflix, Snapchat, and SpaceX and still have billions left.\nApple\'s China sales were down around 29% sequentially and 33% YoY.\nDespite declining unit sales, Apple\'s revenue was boosted by more expensive iPad Pro models.\nApple Pay accounted for 3/4 of contactless payments in the US.\nApple\'s services business (App Store, Apple Music, etc.) was projected to be the size of a Fortune 500 company in the next year.\nApple was reported to be working on a car project called Project Titan, with Bob Mansfield leading it.\nThe Apple Pencil was granted a patent to work with a Mac\'s trackpad.\nApple faced declining iPhone sales, but the company focused on promoting apps and services.\nThe stock price experienced fluctuations after the earnings report, with significant after-hours gains.\nApple\'s market weight rating was reiterated by Wells Fargo, with a target price of $120.00.\n\nPrice Movement: Positive\n\nExplanation: Apple reported strong Q3 2016 earnings, surpassing revenue expectations and delivering robust sales figures across its product lines, including iPhones, iPads, and Macs. This performance exceeded market projections and triggered a nearly 5% increase in the stock\'s after-hours trading. Additionally, Apple\'s substantial cash reserves of $231.5 billion, capable of facilitating major acquisitions, demonstrated the company\'s financial stability and growth potential. Despite challenges in China, Apple\'s diverse revenue sources, including higher-priced iPad Pro models and the dominant Apple Pay in US contactless payments, contributed positively to its overall Price Movement. The promising growth trajectory of Apple\'s services business added further optimism. While facing declining iPhone sales, Apple\'s strategic focus on promoting apps and services reflected adaptability in response to changing market dynamics. The consistent support from Wells Fargo with a reiterated market weight rating and target price also reinforced investor confidence. The stock\'s fluctuations were notable but aligned with the positive earnings report, showcasing the market\'s responsiveness to Apple\'s performance.\n\nFacts:\n2016-04-26\nApple reported its Q2 2016 earnings, missing both profit and revenue estimates.\nApple\'s revenue for the quarter was $50.56 billion, falling short of the estimated $52 billion.\nThe company\'s adjusted earnings per share (EPS) was $1.90, lower than the expected $2.00.\nThis marks the first time in 13 years that Apple experienced a quarterly decline in revenue.\niPhone sales experienced a decline for the first time since its debut in 2007.\nThe company\'s guidance for the next quarter indicates expected sales of $41 billion to $43 billion.\nApple\'s dividend yield increased to 2.3%.\nCEO Tim Cook attributed the challenges to strong macroeconomic headwinds, especially in China.\nDespite the earnings miss, Apple announced plans to raise its dividend and return $50 billion more to shareholders.\nApple\'s stock price experienced a decline of around 4.8% in after-hours trading following the earnings report.\n\nPrice Movement: Negative\n\nExplanation: Apple reported disappointing Q2 2016 earnings, missing both profit and revenue estimates. The company\'s revenue and adjusted earnings per share fell short of expectati ...
# Facts:
# 2025-07-18
# - Analysts have lifted Nvidia's price target to $192, citing the ongoing data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia's position in the market.
# - Josh Brown advised followers to sell Nvidia shares, providing reasons for his recommendation.
# - Nvidia's stock price in 2025 is predicted to be higher, with various sources providing different forecasts.
# - Despite some concerns, some analysts still consider Nvidia a top pick and bullish on its prospects.
# - Nvidia is seeing a surge in market cap and is perceived as a leader in AI technology.
# - The company is expected to have a good quarter, and some analysts see long-term upside potential, especially with AI exports to China.
# - Several analysts and financial institutions have raised Nvidia's price target, showing optimism about the company's performance and growth potential.
#
# 2025-07-19
# - Analysts have raised the price target for NVDA to $192 due to the continued growth in its data center business.
# - Huawei has introduced a new AI compute platform to challenge NVIDIA in the market.
# - There are varying opinions on NVDA stock, with some analysts and experts bullish on its market cap surge and AI leadership.
# - Some experts, like Josh Brown, have given followers "permission" to sell NVDA shares for certain reasons.
# - NVDA stock price predictions for the future vary, with some sources predicting it could reach $200.
# - NVIDIA has been named a top pick ahead of earnings, with some analysts seeing long-term upside potential.
# - Companies like Morgan Stanley and Goldman Sachs have given positive ratings to NVIDIA, further boosting investor confidence in the stock.
#
# 2025-07-20
# - Analysts have lifted the price target for Nvidia (NVDA) to $192, citing the continued data center boom.
# - Huawei has introduced a new AI compute platform to challenge Nvidia.
# - Investor Josh Brown gave followers 'permission' to sell Nvidia shares for certain reasons.
# - There are various stock price predictions for Nvidia in the future, with one suggesting it could reach $200.
# - Nvidia has been named a top pick ahead of earnings by Morgan Stanley.
# - The company's stock has been receiving positive ratings and forecasts from various analysts and firms.
# - Nvidia's AI leadership and market cap surge have been topics of discussion among investors.
# - Jim Cramer mentioned that Nvidia is expected to have a good quarter.
# - Nvidia's long-term upside potential has been highlighted as AI exports to China receive a green light.
# - BofA raised Nvidia's price target based on positive China sales outlook.
# - Dan Niles explained why he turned bullish on Nvidia.
# - Needham stuck with a buy rating on Nvidia and raised the target to $200.
# - Goldman Sachs gave Nvidia a buy rating, with analysts bullish on the company.
# - Tech stocks like Nvidia, AMD, and INTC are forecasted to look bullish in early trading.
#
# 2025-07-21
# - Nvidia's data center business continues to see growth, prompting an analyst to raise the price target for NVDA stock to $192.
# - Huawei has introduced a new AI compute platform that poses a challenge to Nvidia in the AI market.
# - There are varying opinions on whether to buy or sell Nvidia (NVDA) shares, with some analysts bullish on the stock and others cautious.
# - There are price predictions and forecasts for Nvidia stock in the coming years, with some suggesting potential growth to $200 or beyond.
# - Nvidia has been named a top pick by analysts ahead of earnings reports, with some predicting a good quarter for the company.
# - Analysts are optimistic about Nvidia's long-term prospects, particularly as AI technology gains traction in China.
# - Financial firms like BofA and Needham have raised their price targets for Nvidia stock based on factors like China sales outlook and AI leadership.
# - Goldman Sachs has given Nvidia a buy rating, citing reasons why analysts are bullish on the stock.
# - Nvidia is considered one of the top "Magnificent Seven" stocks to buy now, along with other companies like Meta and Microsoft.
#
# 2025-07-22
# - Analysts have lifted Nvidia's (NVDA) price target to $192, citing the ongoing data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the AI space.
# - There are differing opinions on Nvidia's stock (NVDA), with some analysts giving permission to sell shares while others predict a price increase to $200.
# - Despite competition from Huawei, Nvidia remains a top pick, with analysts seeing long-term upside potential as AI technology expands.
# - Jim Cramer believes Nvidia (NVDA) will have a good quarter, while Dan Niles has turned bullish on the company.
# - Needham has a buy rating on Nvidia and has lifted the target price to $200.
# - Goldman Sachs has also given Nvidia (NVDA) a buy rating, and analysts are bullish on the stock.
# - Nvidia is considered one of the three best stocks to buy now, along with META and Microsoft (MSFT).
#
# Price Movement: Positive
#
# Explanation: The numerous positive indications surrounding NVDA stock, including analysts raising the price target to $192 due to the data center boom, and various price predictions forecasting growth to $200, point towards an overall positive Price Movement. Despite challenges from Huawei's new AI compute platform, NVDA's market cap surge, AI leadership, and long-term upside potential have garnered optimism from experts and analysts. Recommendations from financial institutions like Morgan Stanley, Goldman Sachs, and Needham with positive ratings further contribute to the favorable outlook for NVDA stock. The expected good quarter, AI exports to China, and bullish sentiment from notable figures like Jim Cramer and Dan Niles reinforce the company's strong position in the market, signaling a positive trend in the stock's movement.
#
#
#
# Given a list of facts, estimate their overall impact on the price movement of NVDA stock. Give your response in this format:
# (1) Price Movement, which should be either Positive or Negative.
# (2) Explanation, which should be in a single, short paragraph.
# Here are some examples:
# Facts:
# 2016-07-26
# Apple reported Q3 2016 earnings: Revenue of $42.4 billion, beating expectations. They sold 40.4 million iPhones, 9.9 million iPads, and 4.2 million Macs during that quarter.
# Apple's earnings beat expectations, causing the stock to rise by almost 5% in after-hours trading.
# Apple had $231.5 billion in cash reserves, enough to potentially acquire companies like Uber, Tesla, Twitter, Airbnb, Netflix, Snapchat, and SpaceX and still have billions left.
# Apple's China sales were down around 29% sequentially and 33% YoY.
# Despite declining unit sales, Apple's revenue was boosted by more expensive iPad Pro models.
# Apple Pay accounted for 3/4 of contactless payments in the US.
# Apple's services business (App Store, Apple Music, etc.) was projected to be the size of a Fortune 500 company in the next year.
# Apple was reported to be working on a car project called Project Titan, with Bob Mansfield leading it.
# The Apple Pencil was granted a patent to work with a Mac's trackpad.
# Apple faced declining iPhone sales, but the company focused on promoting apps and services.
# The stock price experienced fluctuations after the earnings report, with significant after-hours gains.
# Apple's market weight rating was reiterated by Wells Fargo, with a target price of $120.00.
#
# Price Movement: Positive
#
# Explanation: Apple reported strong Q3 2016 earnings, surpassing revenue expectations and delivering robust sales figures across its product lines, including iPhones, iPads, and Macs. This performance exceeded market projections and triggered a nearly 5% increase in the stock's after-hours trading. Additionally, Apple's substantial cash reserves of $231.5 billion, capable of facilitating major acquisitions, demonstrated the company's financial stability and growth potential. Despite challenges in China, Apple's diverse revenue sources, including higher-priced iPad Pro models and the dominant Apple Pay in US contactless payments, contributed positively to its overall Price Movement. The promising growth trajectory of Apple's services business added further optimism. While facing declining iPhone sales, Apple's strategic focus on promoting apps and services reflected adaptability in response to changing market dynamics. The consistent support from Wells Fargo with a reiterated market weight rating and target price also reinforced investor confidence. The stock's fluctuations were notable but aligned with the positive earnings report, showcasing the market's responsiveness to Apple's performance.
#
# Facts:
# 2016-04-26
# Apple reported its Q2 2016 earnings, missing both profit and revenue estimates.
# Apple's revenue for the quarter was $50.56 billion, falling short of the estimated $52 billion.
# The company's adjusted earnings per share (EPS) was $1.90, lower than the expected $2.00.
# This marks the first time in 13 years that Apple experienced a quarterly decline in revenue.
# iPhone sales experienced a decline for the first time since its debut in 2007.
# The company's guidance for the next quarter indicates expected sales of $41 billion to $43 billion.
# Apple's dividend yield increased to 2.3%.
# CEO Tim Cook attributed the challenges to strong macroeconomic headwinds, especially in China.
# Despite the earnings miss, Apple announced plans to raise its dividend and return $50 billion more to shareholders.
# Apple's stock price experienced a decline of around 4.8% in after-hours trading following the earnings report.
#
# Price Movement: Negative
#
# Explanation: Apple reported disappointing Q2 2016 earnings, missing both profit and revenue estimates. The company's revenue and adjusted earnings per share fell short of expectations, marking the first quarterly revenue decline in 13 years. iPhone sales, a cornerstone of Apple's business, experienced their first-ever decline since the product's debut in 2007. The weaker-than-expected guidance for the next quarter further dampened investor Price Movement. The CEO's acknowledgment of strong macroeconomic headwinds, particularly in China, indicated external challenges affecting the company's performance. Despite announcing plans to increase dividends and return more to shareholders, the stock price plunged around 4.8% in after-hours trading following the earnings report. Overall, these factors collectively indicate a negative Price Movement surrounding AAPL stock due to its underwhelming financial performance and market outlook.
#
# (END OF EXAMPLES)
#
#
#
# Facts:
# 2025-07-18
# - Analysts have lifted Nvidia's price target to $192, citing the ongoing data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia's position in the market.
# - Josh Brown advised followers to sell Nvidia shares, providing reasons for his recommendation.
# - Nvidia's stock price in 2025 is predicted to be higher, with various sources providing different forecasts.
# - Despite some concerns, some analysts still consider Nvidia a top pick and bullish on its prospects.
# - Nvidia is seeing a surge in market cap and is perceived as a leader in AI technology.
# - The company is expected to have a good quarter, and some analysts see long-term upside potential, especially with AI exports to China.
# - Several analysts and financial institutions have raised Nvidia's price target, showing optimism about the company's performance and growth potential.
#
# 2025-07-19
# - Analysts have raised the price target for NVDA to $192 due to the continued growth in its data center business.
# - Huawei has introduced a new AI compute platform to challenge NVIDIA in the market.
# - There are varying opinions on NVDA stock, with some analysts and experts bullish on its market cap surge and AI leadership.
# - Some experts, like Josh Brown, have given followers "permission" to sell NVDA shares for certain reasons.
# - NVDA stock price predictions for the future vary, with some sources predicting it could reach $200.
# - NVIDIA has been named a top pick ahead of earnings, with some analysts seeing long-term upside potential.
# - Companies like Morgan Stanley and Goldman Sachs have given positive ratings to NVIDIA, further boosting investor confidence in the stock.
#
# 2025-07-20
# - Analysts have lifted the price target for Nvidia (NVDA) to $192, citing the continued data center boom.
# - Huawei has introduced a new AI compute platform to challenge Nvidia.
# - Investor Josh Brown gave followers 'permission' to sell Nvidia shares for certain reasons.
# - There are various stock price predictions for Nvidia in the future, with one suggesting it could reach $200.
# - Nvidia has been named a top pick ahead of earnings by Morgan Stanley.
# - The company's stock has been receiving positive ratings and forecasts from various analysts and firms.
# - Nvidia's AI leadership and market cap surge have been topics of discussion among investors.
# - Jim Cramer mentioned that Nvidia is expected to have a good quarter.
# - Nvidia's long-term upside potential has been highlighted as AI exports to China receive a green light.
# - BofA raised Nvidia's price target based on positive China sales outlook.
# - Dan Niles explained why he turned bullish on Nvidia.
# - Needham stuck with a buy rating on Nvidia and raised the target to $200.
# - Goldman Sachs gave Nvidia a buy rating, with analysts bullish on the company.
# - Tech stocks like Nvidia, AMD, and INTC are forecasted to look bullish in early trading.
#
# 2025-07-21
# - Nvidia's data center business continues to see growth, prompting an analyst to raise the price target for NVDA stock to $192.
# - Huawei has introduced a new AI compute platform that poses a challenge to Nvidia in the AI market.
# - There are varying opinions on whether to buy or sell Nvidia (NVDA) shares, with some analysts bullish on the stock and others cautious.
# - There are price predictions and forecasts for Nvidia stock in the coming years, with some suggesting potential growth to $200 or beyond.
# - Nvidia has been named a top pick by analysts ahead of earnings reports, with some predicting a good quarter for the company.
# - Analysts are optimistic about Nvidia's long-term prospects, particularly as AI technology gains traction in China.
# - Financial firms like BofA and Needham have raised their price targets for Nvidia stock based on factors like China sales outlook and AI leadership.
# - Goldman Sachs has given Nvidia a buy rating, citing reasons why analysts are bullish on the stock.
# - Nvidia is considered one of the top "Magnificent Seven" stocks to buy now, along with other companies like Meta and Microsoft.
#
# 2025-07-22
# - Analysts have lifted Nvidia's (NVDA) price target to $192, citing the ongoing data center boom.
# - Huawei has introduced a new AI compute platform that challenges Nvidia in the AI space.
# - There are differing opinions on Nvidia's stock (NVDA), with some analysts giving permission to sell shares while others predict a price increase to $200.
# - Despite competition from Huawei, Nvidia remains a top pick, with analysts seeing long-term upside potential as AI technology expands.
# - Jim Cramer believes Nvidia (NVDA) will have a good quarter, while Dan Niles has turned bullish on the company.
# - Needham has a buy rating on Nvidia and has lifted the target price to $200.
# - Goldman Sachs has also given Nvidia (NVDA) a buy rating, and analysts are bullish on the stock.
# - Nvidia is considered one of the three best stocks to buy now, along with META and Microsoft (MSFT).
#
# Price Movement:
#
#
#
# {'user_input': 'Given a list of facts, estimate their overall impact on the price movement of NVDA stock. Give your response in this format:\n(1) Price Movement, which should be either Positive or Negative.\n(2) Explanation, which should be in a single, short paragraph.\nHere are some examples:\nFacts:\n2016-07-26\nApple reported Q3 2016 earnings: Revenue of $42.4 billion, beating expectations. They sold 40.4 million iPhones, 9.9 million iPads, and 4.2 million Macs during that quarter.\nApple\'s earnings beat expectations, causing the stock to rise by almost 5% in after-hours trading.\nApple had $231.5 billion in cash reserves, enough to potentially acquire companies like Uber, Tesla, Twitter, Airbnb, Netflix, Snapchat, and SpaceX and still have billions left.\nApple\'s China sales were down around 29% sequentially and 33% YoY.\nDespite declining unit sales, Apple\'s revenue was boosted by more expensive iPad Pro models.\nApple Pay accounted for 3/4 of contactless payments in the US.\nApple\'s services business (App Store, Apple Music, etc.) was projected to be the size of a Fortune 500 company in the next year.\nApple was reported to be working on a car project called Project Titan, with Bob Mansfield leading it.\nThe Apple Pencil was granted a patent to work with a Mac\'s trackpad.\nApple faced declining iPhone sales, but the company focused on promoting apps and services.\nThe stock price experienced fluctuations after the earnings report, with significant after-hours gains.\nApple\'s market weight rating was reiterated by Wells Fargo, with a target price of $120.00.\n\nPrice Movement: Positive\n\nExplanation: Apple reported strong Q3 2016 earnings, surpassing revenue expectations and delivering robust sales figures across its product lines, including iPhones, iPads, and Macs. This performance exceeded market projections and triggered a nearly 5% increase in the stock\'s after-hours trading. Additionally, Apple\'s substantial cash reserves of $231.5 billion, capable of facilitating major acquisitions, demonstrated the company\'s financial stability and growth potential. Despite challenges in China, Apple\'s diverse revenue sources, including higher-priced iPad Pro models and the dominant Apple Pay in US contactless payments, contributed positively to its overall Price Movement. The promising growth trajectory of Apple\'s services business added further optimism. While facing declining iPhone sales, Apple\'s strategic focus on promoting apps and services reflected adaptability in response to changing market dynamics. The consistent support from Wells Fargo with a reiterated market weight rating and target price also reinforced investor confidence. The stock\'s fluctuations were notable but aligned with the positive earnings report, showcasing the market\'s responsiveness to Apple\'s performance.\n\nFacts:\n2016-04-26\nApple reported its Q2 2016 earnings, missing both profit and revenue estimates.\nApple\'s revenue for the quarter was $50.56 billion, falling short of the estimated $52 billion.\nThe company\'s adjusted earnings per share (EPS) was $1.90, lower than the expected $2.00.\nThis marks the first time in 13 years that Apple experienced a quarterly decline in revenue.\niPhone sales experienced a decline for the first time since its debut in 2007.\nThe company\'s guidance for the next quarter indicates expected sales of $41 billion to $43 billion.\nApple\'s dividend yield increased to 2.3%.\nCEO Tim Cook attributed the challenges to strong macroeconomic headwinds, especially in China.\nDespite the earnings miss, Apple announced plans to raise its dividend and return $50 billion more to shareholders.\nApple\'s stock price experienced a decline of around 4.8% in after-hours trading following the earnings report.\n\nPrice Movement: Negative\n\nExplanation: Apple reported disappointing Q2 2016 earnings, missing both profit and revenue estimates. The company\'s revenue and adjusted earnings per share fell short of expectati ...
# Facts:
# 2025-07-17
# - An analyst raised the price target for NVIDIA (NVDA) to $192 due to the continued growth in its data center business.
# - Huawei introduced a new AI compute platform that challenges NVIDIA's position in the market.
# - There are opinions and predictions about NVIDIA's stock price performance in the future, with some analysts bullish on the company.
# - Josh Brown suggested selling NVIDIA shares, citing reasons for doing so.
# - NVIDIA was named a top pick ahead of earnings by Morgan Stanley and received a buy rating from Goldman Sachs.
# - Analysts see long-term upside for NVIDIA as AI exports to China get the green light.
# - NVIDIA is forecasted to have a good quarter, with an increased price target by Bank of America.
# - Dan Niles turned bullish on NVIDIA, explaining his reasoning for his positive outlook on the stock.
# - Needham maintained a Buy rating on NVIDIA and raised the target price to $200.
# - Tech stocks like NVIDIA, AMD, and INTC are looking bullish in early trading according to some reports.
#
# 2025-07-18
# -Nvidia's data center business is experiencing continued growth, prompting an analyst to raise the price target for NVDA stock to $192.
# -There is competition for Nvidia from Huawei with a new AI compute platform challenging Nvidia's position in the market.
# -There are conflicting opinions on NVDA stock, with Josh Brown giving followers "permission" to sell Nvidia shares due to reasons not specified.
# -There are varying stock price predictions for Nvidia in 2025, with some sources bullish on the stock reaching $200.
# -Morgan Stanley named Nvidia a top pick ahead of earnings, suggesting positive outlook for the company.
# -Various analysts and firms have raised price targets for Nvidia, with BofA raising the target based on China sales outlook and Needham sticking with a buy rating and lifting the target to $200.
# -Jim Cramer believes Nvidia will have a good quarter, while Dan Niles explains his bullish stance on Nvidia.
# -Overall, analysts see long-term upside for Nvidia as AI exports to China get the green light and the company continues to lead in AI technology.
# -Nvidia has recently received a buy rating from Goldman Sachs, further contributing to the positive sentiment around the stock.
# -Overall, Nvidia is considered one of the best Magnificent Seven stocks to buy now for potential growth.
#
# 2025-07-19
# - Analysts have lifted Nvidia's price target to $192, with the company experiencing a data center boom.
# - Huawei has unveiled a new AI compute platform to challenge Nvidia in the AI space.
# - There are differing opinions on whether to sell or invest in Nvidia shares, with Josh Brown giving followers "permission" to sell.
# - There are stock price predictions for Nvidia in 2025, with some sources bullish on the company's future.
# - Nvidia's market cap has surged, and the company is seen as a leader in AI technology.
# - Nvidia has been named a top pick by analysts ahead of earnings reports.
# - There are positive outlooks on Nvidia's performance, with some analysts seeing long-term upside potential as AI exports to China get a green light.
# - Analysts at Needham have reiterated their buy rating on Nvidia and raised their price target to $200.
# - Goldman Sachs has given Nvidia a buy rating, citing reasons for being bullish on the company.
# - Nvidia is among the "Magnificent Seven Stocks" recommended for investment.
#
# 2025-07-20
# 1. Analysts have raised the price target for NVIDIA (NVDA) to $192, citing a continued data center boom.
# 2. Huawei has introduced a new AI compute platform, challenging NVIDIA in the AI space.
# 3. There is a mixed opinion on investing in NVIDIA, with some analysts giving permission to sell shares while others name it a top pick.
# 4. NVIDIA's stock price is predicted to potentially reach $200 in the future.
# 5. Financial experts have a bullish outlook on tech stocks like NVDA, AMD, and INTC.
# 6. Analysts anticipate long-term upside for NVIDIA as AI exports to China receive approval.
# 7. Several analysts and financial firms have raised their price targets for NVIDIA, with some setting it at $200.
# 8. Jim Cramer predicts that NVIDIA will have a good quarter based on their performance.
# 9. NVIDIA has been named a top pick ahead of earnings by Morgan Stanley.
# 10. Recent reports indicate that NVIDIA just received a buy rating from Goldman Sachs.
#
# 2025-07-21
# - Analysts have raised price targets for NVDA, with predictions ranging up to $200.
# - Huawei has unveiled a new AI compute platform that challenges Nvidia in the AI space.
# - There is debate among experts such as Josh Brown on whether to buy or sell NVDA shares.
# - NVDA is considered a top pick by analysts ahead of earnings reports.
# - NVDA has been named a leader in AI technology and has seen a surge in market cap.
# - Nvidia's long-term upside is seen by analysts, especially as their AI technology exports to China get approval.
# - Jim Cramer believes NVDA will have a good quarter.
# - NVDA stock is predicted to continue its bullish trend in early trading.
# - Dan Niles has turned bullish on NVDA.
# - Needham has a buy rating on NVDA and has raised its target price to $200.
#
# Price Movement: Positive
#
# Explanation: The overall sentiment around NVIDIA (NVDA) stock remains positive as analysts raise price targets to $192, driven by the company's strong growth in the data center business. Despite competition from Huawei's new AI compute platform challenging NVIDIA's position, the stock is considered a top pick by multiple analysts and financial firms. Conflicting opinions on selling shares from experts like Josh Brown are outweighed by bullish outlooks from Morgan Stanley, BofA, and Needham, with price targets reaching $200. The continued recognition of NVDA as a leader in AI technology, positive performance predictions, and buy ratings from Goldman Sachs further contribute to the optimistic Price Movement forecasted for the stock. Overall, the bullish sentiment surrounding NVDA aligns with projections of long-term upside potential, especially in the context of AI exports to China and the tech sector's bullish trend, indicating a positive price trajectory for NVDA.
#
#
#
# Given a list of facts, estimate their overall impact on the price movement of NVDA stock. Give your response in this format:
# (1) Price Movement, which should be either Positive or Negative.
# (2) Explanation, which should be in a single, short paragraph.
# Here are some examples:
# Facts:
# 2016-07-26
# Apple reported Q3 2016 earnings: Revenue of $42.4 billion, beating expectations. They sold 40.4 million iPhones, 9.9 million iPads, and 4.2 million Macs during that quarter.
# Apple's earnings beat expectations, causing the stock to rise by almost 5% in after-hours trading.
# Apple had $231.5 billion in cash reserves, enough to potentially acquire companies like Uber, Tesla, Twitter, Airbnb, Netflix, Snapchat, and SpaceX and still have billions left.
# Apple's China sales were down around 29% sequentially and 33% YoY.
# Despite declining unit sales, Apple's revenue was boosted by more expensive iPad Pro models.
# Apple Pay accounted for 3/4 of contactless payments in the US.
# Apple's services business (App Store, Apple Music, etc.) was projected to be the size of a Fortune 500 company in the next year.
# Apple was reported to be working on a car project called Project Titan, with Bob Mansfield leading it.
# The Apple Pencil was granted a patent to work with a Mac's trackpad.
# Apple faced declining iPhone sales, but the company focused on promoting apps and services.
# The stock price experienced fluctuations after the earnings report, with significant after-hours gains.
# Apple's market weight rating was reiterated by Wells Fargo, with a target price of $120.00.
#
# Price Movement: Positive
#
# ...
# Facts:
# 2025-07-15
# - Analysts lifted Nvidia's price target to $192 due to the continued data center boom.
# - Huawei challenged Nvidia with a new AI compute platform.
# - Josh Brown gave followers 'permission' to sell Nvidia shares for unspecified reasons.
# - There are varying opinions and predictions about Nvidia's stock price in 2025.
# - Nvidia stock surged due to market cap and AI leadership.
# - Nvidia's stock could potentially reach $200 according to Forbes.
# - Tech stocks like Nvidia, AMD, and INTC are forecasted to look bullish in early trading.
# - Nvidia was named a top pick ahead of earnings by Morgan Stanley.
# - Jim Cramer believes Nvidia will have a good quarter.
# - BofA raised Nvidia's price target based on China sales outlook.
# - Dan Niles turned bullish on Nvidia for undisclosed reasons.
# - Analysts see long-term upside for Nvidia as AI exports to China get approved.
# - Needham stuck with a buy rating on Nvidia and lifted the target to $200.
# - Nvidia received a buy rating from Goldman Sachs for bullish reasons.
# - Nvidia is considered one of the 3 best Magnificent Seven stocks to buy now alongside META and MSFT.
#
# 2025-07-16
# -Nvidia's data center business is experiencing growth, leading an analyst to increase the price target for NVDA stock to $192.
# -Huawei has introduced a new AI compute platform that challenges Nvidia in the market.
# -Josh Brown, a financial analyst, advised followers to sell their Nvidia shares for specific reasons.
# -There are predictions and opinions on Nvidia's stock price for 2025, with some sources bullish on the company's performance.
# -Nvidia is being named a top pick by some analysts ahead of its earnings report.
# -Various analysts and financial institutions are raising price targets for Nvidia stock based on factors like China sales outlook and AI leadership.
# -Nvidia's stock price is experiencing bullish trends in early trading, along with other tech stocks like AMD and INTC.
# -Experts like Jim Cramer and Dan Niles have expressed positive sentiments towards Nvidia's performance and outlook.
# -Needham reiterates a buy rating for Nvidia stock and raises the target price to $200.
# -Goldman Sachs has given Nvidia a buy rating, with analysts optimistic about the company's future prospects.
# -Nvidia is identified as one of the best "Magnificent Seven" stocks to buy now, alongside companies like Meta and Microsoft.
#
# Price Movement: Positive
#
# Explanation: The various positive factors surrounding Nvidia, such as the increased price target by analysts, strong data center business growth, and bullish sentiments from experts like Jim Cramer and Dan Niles, contribute to a positive forecast for NVDA stock price movement. Factors like the introduction of a new AI compute platform by Huawei and raised price targets from financial institutions based on China sales outlook and AI leadership highlight the company's growth potential. The overall trend of optimistic predictions, top picks by analysts, and the stock's bullish performance in early trading indicate a favorable outlook for Nvidia's stock price in response to recent developments and expert recommendations.
#
#
#
# Given a list of facts, estimate their overall impact on the price movement of NVDA stock. Give your response in this format:
# (1) Price Movement, which should be either Positive or Negative.
# (2) Explanation, which should be in a single, short paragraph.
# Here are some examples:
# Facts:
# 2016-07-26
# Apple reported Q3 2016 earnings: Revenue of $42.4 billion, beating expectations. They sold 40.4 million iPhones, 9.9 million iPads, and 4.2 million Macs during that quarter.
# Apple's earnings beat expectations, causing the stock to rise by almost 5% in after-hours trading.
# Apple had $231.5 billion in cash reserves, enough to potentially acquire companies like Uber, Tesla, Twitter, Airbnb, Netflix, Snapchat, and SpaceX and still have billions left.
# Apple's China sales were down around 29% sequentially and 33% YoY.
# Despite declining unit sales, Apple's revenue was boosted by more expensive iPad Pro models.
# Apple Pay accounted for 3/4 of contactless payments in the US.
# Apple's services business (App Store, Apple Music, etc.) was projected to be the size of a Fortune 500 company in the next year.
# Apple was reported to be working on a car project called Project Titan, with Bob Mansfield leading it.
# The Apple Pencil was granted a patent to work with a Mac's trackpad.
# Apple faced declining iPhone sales, but the company focused on promoting apps and services.
# The stock price experienced fluctuations after the earnings report, with significant after-hours gains.
# Apple's market weight rating was reiterated by Wells Fargo, with a target price of $120.00.
#
# Price Movement: Positive
#
# Explanation: Apple reported strong Q3 2016 earnings, surpassing revenue expectations and delivering robust sales figures across its product lines, including iPhones, iPads, and Macs. This performance exceeded market projections and triggered a nearly 5% increase in the stock's after-hours trading. Additionally, Apple's substantial cash reserves of $231.5 billion, capable of facilitating major acquisitions, demonstrated the company's financial stability and growth potential. Despite challenges in China, Apple's diverse revenue sources, including higher-priced iPad Pro models and the dominant Apple Pay in US contactless payments, contributed positively to its overall Price Movement. The promising growth trajectory of Apple's services business added further optimism. While facing declining iPhone sales, Apple's strategic focus on promoting apps and services reflected adaptability in response to changing market dynamics. The consistent support from Wells Fargo with a reiterated market weight rating and target price also reinforced investor confidence. The stock's fluctuations were notable but aligned with the positive earnings report, showcasing the market's responsiveness to Apple's performance.
#
# Facts:
# 2016-04-26
# Apple reported its Q2 2016 earnings, missing both profit and revenue estimates.
# Apple's revenue for the quarter was $50.56 billion, falling short of the estimated $52 billion.
# The company's adjusted earnings per share (EPS) was $1.90, lower than the expected $2.00.
# This marks the first time in 13 years that Apple experienced a quarterly decline in revenue.
# iPhone sales experienced a decline for the first time since its debut in 2007.
# The company's guidance for the next quarter indicates expected sales of $41 billion to $43 billion.
# Apple's dividend yield increased to 2.3%.
# CEO Tim Cook attributed the challenges to strong macroeconomic headwinds, especially in China.
# Despite the earnings miss, Apple announced plans to raise its dividend and return $50 billion more to shareholders.
# Apple's stock price experienced a decline of around 4.8% in after-hours trading following the earnings report.
#
# Price Movement: Negative
#
# Explanation: Apple reported disappointing Q2 2016 earnings, missing both profit and revenue estimates. The company's revenue and adjusted earnings per share fell short of expectations, marking the first quarterly revenue decline in 13 years. iPhone sales, a cornerstone of Apple's business, experienced their first-ever decline since the product's debut in 2007. The weaker-than-expected guidance for the next quarter further dampened investor Price Movement. The CEO's acknowledgment of strong macroeconomic headwinds, particularly in China, indicated external challenges affecting the company's performance. Despite announcing plans to increase dividends and return more to shareholders, the stock price plunged around 4.8% in after-hours trading following the earnings report. Overall, these factors collectively indicate a negative Price Movement surrounding AAPL stock due to its underwhelming financial performance and market outlook.
#
# (END OF EXAMPLES)
#
#
#
# Facts:
# 2025-07-15
# - Analysts lifted Nvidia's price target to $192 due to the continued data center boom.
# - Huawei challenged Nvidia with a new AI compute platform.
# - Josh Brown gave followers 'permission' to sell Nvidia shares for unspecified reasons.
# - There are varying opinions and predictions about Nvidia's stock price in 2025.
# - Nvidia stock surged due to market cap and AI leadership.
# - Nvidia's stock could potentially reach $200 according to Forbes.
# - Tech stocks like Nvidia, AMD, and INTC are forecasted to look bullish in early trading.
# - Nvidia was named a top pick ahead of earnings by Morgan Stanley.
# - Jim Cramer believes Nvidia will have a good quarter.
# - BofA raised Nvidia's price target based on China sales outlook.
# - Dan Niles turned bullish on Nvidia for undisclosed reasons.
# - Analysts see long-term upside for Nvidia as AI exports to China get approved.
# - Needham stuck with a buy rating on Nvidia and lifted the target to $200.
# - Nvidia received a buy rating from Goldman Sachs for bullish reasons.
# - Nvidia is considered one of the 3 best Magnificent Seven stocks to buy now alongside META and MSFT.
#
# 2025-07-16
# -Nvidia's data center business is experiencing growth, leading an analyst to increase the price target for NVDA stock to $192.
# -Huawei has introduced a new AI compute platform that challenges Nvidia in the market.
# -Josh Brown, a financial analyst, advised followers to sell their Nvidia shares for specific reasons.
# -There are predictions and opinions on Nvidia's stock price for 2025, with some sources bullish on the company's performance.
# -Nvidia is being named a top pick by some analysts ahead of its earnings report.
# -Various analysts and financial institutions are raising price targets for Nvidia stock based on factors like China sales outlook and AI leadership.
# -Nvidia's stock price is experiencing bullish trends in early trading, along with other tech stocks like AMD and INTC.
# -Experts like Jim Cramer and Dan Niles have expressed positive sentiments towards Nvidia's performance and outlook.
# -Needham reiterates a buy rating for Nvidia stock and raises the target price to $200.
# -Goldman Sachs has given Nvidia a buy rating, with analysts optimistic about the company's future prospects.
# -Nvidia is identified as one of the best "Magnificent Seven" stocks to buy now, alongside companies like Meta and Microsoft.
#
# Price Movement:
#
#
#
# {'user_input': 'Given a list of facts, estimate their overall impact on the price movement of NVDA stock. Give your response in this format:\n(1) Price Movement, which should be either Positive or Negative.\n(2) Explanation, which should be in a single, short paragraph.\nHere are some examples:\nFacts:\n2016-07-26\nApple reported Q3 2016 earnings: Revenue of $42.4 billion, beating expectations. They sold 40.4 million iPhones, 9.9 million iPads, and 4.2 million Macs during that quarter.\nApple\'s earnings beat expectations, causing the stock to rise by almost 5% in after-hours trading.\nApple had $231.5 billion in cash reserves, enough to potentially acquire companies like Uber, Tesla, Twitter, Airbnb, Netflix, Snapchat, and SpaceX and still have billions left.\nApple\'s China sales were down around 29% sequentially and 33% YoY.\nDespite declining unit sales, Apple\'s revenue was boosted by more expensive iPad Pro models.\nApple Pay accounted for 3/4 of contactless payments in the US.\nApple\'s services business (App Store, Apple Music, etc.) was projected to be the size of a Fortune 500 company in the next year.\nApple was reported to be working on a car project called Project Titan, with Bob Mansfield leading it.\nThe Apple Pencil was granted a patent to work with a Mac\'s trackpad.\nApple faced declining iPhone sales, but the company focused on promoting apps and services.\nThe stock price experienced fluctuations after the earnings report, with significant after-hours gains.\nApple\'s market weight rating was reiterated by Wells Fargo, with a target price of $120.00.\n\nPrice Movement: Positive\n\nExplanation: Apple reported strong Q3 2016 earnings, surpassing revenue expectations and delivering robust sales figures across its product lines, including iPhones, iPads, and Macs. This performance exceeded market projections and triggered a nearly 5% increase in the stock\'s after-hours trading. Additionally, Apple\'s substantial cash reserves of $231.5 billion, capable of facilitating major acquisitions, demonstrated the company\'s financial stability and growth potential. Despite challenges in China, Apple\'s diverse revenue sources, including higher-priced iPad Pro models and the dominant Apple Pay in US contactless payments, contributed positively to its overall Price Movement. The promising growth trajectory of Apple\'s services business added further optimism. While facing declining iPhone sales, Apple\'s strategic focus on promoting apps and services reflected adaptability in response to changing market dynamics. The consistent support from Wells Fargo with a reiterated market weight rating and target price also reinforced investor confidence. The stock\'s fluctuations were notable but aligned with the positive earnings report, showcasing the market\'s responsiveness to Apple\'s performance.\n\nFacts:\n2016-04-26\nApple reported its Q2 2016 earnings, missing both profit and revenue estimates.\nApple\'s revenue for the quarter was $50.56 billion, falling short of the estimated $52 billion.\nThe company\'s adjusted earnings per share (EPS) was $1.90, lower than the expected $2.00.\nThis marks the first time in 13 years that Apple experienced a quarterly decline in revenue.\niPhone sales experienced a decline for the first time since its debut in 2007.\nThe company\'s guidance for the next quarter indicates expected sales of $41 billion to $43 billion.\nApple\'s dividend yield increased to 2.3%.\nCEO Tim Cook attributed the challenges to strong macroeconomic headwinds, especially in China.\nDespite the earnings miss, Apple announced plans to raise its dividend and return $50 billion more to shareholders.\nApple\'s stock price experienced a decline of around 4.8% in after-hours trading following the earnings report.\n\nPrice Movement: Negative\n\nExplanation: Apple reported disappointing Q2 2016 earnings, missing both profit and revenue estimates. The company\'s revenue and adjusted earnings per share fell short of expectati ...
# Finished Trial 1, Correct: 6, Incorrect: 0
# Finished Trial 2, Correct: 6, Incorrect: 0

# %%
# clear GPU memory
with torch.no_grad():
    torch.cuda.empty_cache()

# %% [markdown]
# ### 2. train_reward_model.py

# %%
# Train reward model
train_reward_model(args)
merge_peft_adapter(model_name=args.reward_adapter, output_name=args.reward_model_name)
# Out:
# dataset_name:  ./datasets/
# device_map:  auto
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at lmsys/vicuna-7b-v1.5-16k and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# trainable params: 4,198,400 || all params: 6,611,546,112 || trainable%: 0.0635010318143267
# train_dataset:  6
# train_dataset:  6
# eval_dataset:  6
# eval_dataset:  6
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2624: UserWarning: `max_length` is ignored when `padding`=`True` and there is no truncation strategy. To pad to max length, use `padding='max_length'`.
#   warnings.warn(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/torch/_dynamo/eval_frame.py:745: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 00:00, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving last checkpoint of the model
# peft_config:  LoraConfig(peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path='lmsys/vicuna-7b-v1.5-16k', revision=None, task_type='SEQ_CLS', inference_mode=True, r=8, target_modules={'q_proj', 'v_proj'}, lora_alpha=16, lora_dropout=0.05, fan_in_fan_out=False, bias='none', modules_to_save=None, init_lora_weights=True, layers_to_transform=None, layers_pattern=None, rank_pattern={}, alpha_pattern={})
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/transformers/generation/configuration_utils.py:508: UserWarning: The generation config instance is invalid -- `.validate()` throws warnings and/or exceptions. Fix these issues to save the configuration. This warning will be raised to an exception in v4.34.
#
# Thrown during validation:
# `do_sample` is set to `False`. However, `temperature` is set to `None` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(

# %%
# clear GPU memory
torch.cuda.empty_cache()
torch.cuda.ipc_collect()

# %% [markdown]
# ### 3. train_rl.py

# %%
from dataclasses import dataclass, field
from typing import Optional

import torch
from accelerate import Accelerator
from datasets import load_dataset
from peft import LoraConfig, prepare_model_for_kbit_training # prepare_model_for_int8_training
from tqdm import tqdm
from transformers import Adafactor, AutoTokenizer, HfArgumentParser, pipeline, BitsAndBytesConfig
from transformers import LlamaTokenizer, LlamaConfig, LlamaForSequenceClassification, LlamaForCausalLM

from trl import AutoModelForCausalLMWithValueHead, PPOConfig, PPOTrainer, set_seed
from trl.core import LengthSampler
import os


# DEFAULT_PAD_TOKEN = "[PAD]"
# DEFAULT_EOS_TOKEN = "</s>"
# DEFAULT_BOS_TOKEN = "</s>"
# DEFAULT_UNK_TOKEN = "</s>"

tqdm.pandas()


script_args = args

reward_model_name = script_args.reward_model_name

# dataset_name = "lvwerra/stack-exchange-paired"
dataset_name = script_args.datasets_dir
print("dataset_name: ", dataset_name)

config = PPOConfig(
    model_name=script_args.rl_base_model,
    learning_rate=script_args.rl_learning_rate,
    log_with=script_args.log_with,
    batch_size=script_args.batch_size,
    mini_batch_size=script_args.mini_batch_size,
    gradient_accumulation_steps=script_args.rl_gradient_accumulation_steps,
    optimize_cuda_cache=True,
    early_stopping=script_args.early_stopping,
    target_kl=script_args.target_kl,
    ppo_epochs=script_args.ppo_epochs,
    seed=script_args.seed,
)

# train_dataset = load_dataset("lvwerra/stack-exchange-paired", data_dir="data/rl", split="train")
# train_dataset = train_dataset.select(range(100000))
train_dataset = load_dataset(dataset_name, split="train")
# train_dataset = train_dataset.select(range(100))
# We then define the arguments to pass to the sentiment analysis pipeline.
# We set `return_all_scores` to True to get the sentiment score for each token.
# sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 16, "truncation": True}
sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 1, "truncation": True}

# tokenizer = AutoTokenizer.from_pretrained(script_args.tokenizer_name)
# GPT-2 tokenizer has a pad token, but it is not eos_token by default. We need to set it to eos_token.
# only for this model.

if "llama" in script_args.tokenizer_name or "vicuna" in script_args.rl_base_model or "Vicuna" in script_args.rl_base_model:
    tokenizer = LlamaTokenizer.from_pretrained(script_args.tokenizer_name)
else:
    tokenizer = AutoTokenizer.from_pretrained(script_args.tokenizer_name)


# if "llama" in script_args.tokenizer_name or "vicuna" in script_args.rl_base_model or "Vicuna" in script_args.rl_base_model:
#     tokenizer.add_special_tokens(
#         {
#             "eos_token": DEFAULT_EOS_TOKEN,
#             "bos_token": DEFAULT_BOS_TOKEN,
#             "unk_token": DEFAULT_UNK_TOKEN,
#             "pad_token": DEFAULT_PAD_TOKEN,
#         }
#     )
# else:
#     tokenizer.pad_token = tokenizer.eos_token


# Below is an example function to build the dataset. In our case, we use the IMDB dataset
# from the `datasets` library. One should customize this function to train the model on
# its own dataset.
def build_dataset(
    tokenizer, dataset_name="lvwerra/stack-exchange-paired", input_min_text_length=2, input_max_text_length=8
):
    """
    Build dataset for training. This builds the dataset from `load_dataset`, one should
    customize this function to train the model on its own dataset.

    Args:
        dataset_name (`str`):
            The name of the dataset to be loaded.

    Returns:
        dataloader (`torch.utils.data.DataLoader`):
            The dataloader for the dataset.
    """

    # load imdb with datasets
    # ds = load_dataset(dataset_name, data_dir="data/rl", split="train")
    ds = load_dataset(dataset_name, split="train")
    original_columns = ds.column_names
    num_proc = 1 #24

    def preprocess_function(examples):
        new_examples = {
            "query": [],
            "input_ids": [],
        }
        # for question in examples["question"]:
        for question in examples["user_input"]:
            query = "Question: " + question + "\n\nAnswer: "
            tokenized_question = tokenizer(query, truncation=True)
            new_examples["query"].append(query)
            new_examples["input_ids"].append(tokenized_question["input_ids"])

        return new_examples

    ds = train_dataset.map(
        preprocess_function,
        batched=True,
        num_proc=num_proc,
        remove_columns=original_columns,
    )
    # ds = ds.filter(lambda x: len(x["input_ids"]) < 512, batched=False)

    ds.set_format(type="torch")
    return ds

# We retrieve the dataloader by calling the `build_dataset` function.
# dataset = build_dataset(tokenizer)
dataset = build_dataset(tokenizer, dataset_name=dataset_name)


def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])


# set seed before initializing value head for deterministic eval
set_seed(config.seed)

# Now let's build the model, the reference model, and the tokenizer.
current_device = Accelerator().local_process_index

lora_config = LoraConfig(
    r=8, #16, # Oli
    lora_alpha=16, #32,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
)

model = AutoModelForCausalLMWithValueHead.from_pretrained(
    config.model_name,
    # load_in_4bit=True, # Oli
    # device_map={"": current_device},
    device_map="auto",
    peft_config=lora_config,
    # layer_norm_names=[],
    # torch_dtype=torch.float16, # Oli
    quantization_config=BitsAndBytesConfig(
        load_in_4bit=True,  # Oli
        bnb_4bit_quant_type="nf4", # Oli
        bnb_4bit_use_double_quant=True, # Oli
        # bnb_4bit_compute_dtype=torch.bfloat16, # Oli
        # bnb_4bit_quant_storage=torch.bfloat16, # Oli
        llm_int8_enable_fp32_cpu_offload=True) 
)
# model = AutoModelForCausalLMWithValueHead.from_pretrained(
# config.model_name,
# load_in_4bit=True,
# # device_map={"": current_device},
# device_map="auto",
# peft_config=lora_config,
# # layer_norm_names=[],
# # torch_dtype=torch.float16,
# quantization_config=BitsAndBytesConfig(llm_int8_enable_fp32_cpu_offload=True))
print("finetune model: ", config.model_name, type(model))
print("finetune model's is_loaded_in_4bit: ", model.is_loaded_in_4bit)

optimizer = None
if script_args.adafactor:
    optimizer = Adafactor(
        filter(lambda p: p.requires_grad, model.parameters()),
        scale_parameter=False,
        relative_step=False,
        warmup_init=False,
        lr=config.learning_rate,
    )
# We then build the PPOTrainer, passing the model, the reference model, the tokenizer
ppo_trainer = PPOTrainer(
    config,
    model,
    ref_model=None,
    tokenizer=tokenizer,
    dataset=dataset,
    data_collator=collator,
    optimizer=optimizer,
)

# We then build the sentiment analysis pipeline, passing the model name and the
# sentiment analysis pipeline arguments. Let's also make sure to set the device
# to the same device as the PPOTrainer.
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"  # to avoid a ` pipeline` bug
print("device: ", device)


print("reward_model_name: ", reward_model_name)
#! my self code to try peft reward model
# reward_model = LlamaForSequenceClassification.from_pretrained(
#     reward_model_name,
#     load_in_4bit=True,
#     device_map="auto",
#     torch_dtype=torch.float16,
# )
# print("reward_model: ", type(reward_model))
# print("reward_model is_loaded_in_4bit: ", reward_model.is_loaded_in_4bit)

# reward_model = prepare_model_for_int8_training(reward_model)
# reward_model_config = LlamaConfig.from_pretrained(reward_model_name)

sentiment_pipe = pipeline(
    "sentiment-analysis",
    model=reward_model_name,
    # model=reward_model,
    # config=reward_model_config,
    device_map="auto",
    # TypeError: LlamaForSequenceClassification.__init__() got an unexpected keyword argument 'peft_config'
    model_kwargs={"load_in_4bit": True},
    tokenizer=tokenizer,
    # torch_dtype=torch.float16,
)

# We then define the arguments to pass to the `generate` function. These arguments
# are passed to the `generate` function of the PPOTrainer, which is a wrapper around
# the `generate` function of the trained model.
generation_kwargs = {
    # "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.pad_token_id,
    "eos_token_id": 100_000,
}
output_min_length = 32
output_max_length = script_args.output_max_length
output_length_sampler = LengthSampler(output_min_length, output_max_length)
# Out:
# dataset_name:  ./datasets/
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# finetune model:  ./saved_models/lora-Vicuna-adapter-merged <class 'trl.models.modeling_value_head.AutoModelForCausalLMWithValueHead'>
# finetune model's is_loaded_in_4bit:  True
# device:  0
# reward_model_name:  ./saved_models/reward_model_vicuna-7b-adapter-merged
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at ./saved_models/reward_model_vicuna-7b-adapter-merged and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
for epoch, batch in tqdm(enumerate(ppo_trainer.dataloader)):
    
    # if len(batch['query'][0])>7000: # limit of my A5000 GPU
    #     continue

    # print(batch) # if want to take a look at the query

    question_tensors = batch["input_ids"]

    response_tensors = ppo_trainer.generate(
        question_tensors,
        return_prompt=False,
        length_sampler=output_length_sampler,
        **generation_kwargs,
    )
    batch["response"] = tokenizer.batch_decode(response_tensors, skip_special_tokens=True)

    # Compute sentiment score
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    rewards = [torch.tensor(output[0]["score"] - script_args.reward_baseline) for output in pipe_outputs]

    # Run PPO step
    stats = ppo_trainer.step(question_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)

    if script_args.save_freq and epoch and epoch % script_args.save_freq == 0:
        ppo_trainer.save_pretrained(script_args.output_dir + f"step_{epoch}")

    ppo_trainer.save_pretrained(script_args.output_dir + "step_saved")
# Out:
# 6it [00:00, 696.61it/s]

# %%
ppo_trainer.save_pretrained(args.output_dir + "final")
merge_peft_adapter(model_name=args.output_dir + "final", output_name="./saved_models/sep_model", RF_finetune=True)
# Out:
# /home/yc_yam/anaconda3/envs/sep/lib/python3.10/site-packages/trl/trainer/ppo_trainer.py:1356: UserWarning: Cannot retrieve user information assuming you are running in offline mode.
#   warnings.warn("Cannot retrieve user information assuming you are running in offline mode.")
# peft_config:  LoraConfig(peft_type=<PeftType.LORA: 'LORA'>, auto_mapping=None, base_model_name_or_path='./saved_models/lora-Vicuna-adapter-merged', revision=None, task_type='CAUSAL_LM', inference_mode=True, r=8, target_modules={'v_proj', 'q_proj'}, lora_alpha=16, lora_dropout=0.05, fan_in_fan_out=False, bias='none', modules_to_save=None, init_lora_weights=True, layers_to_transform=None, layers_pattern=None, rank_pattern={}, alpha_pattern={})
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
